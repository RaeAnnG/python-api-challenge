# %%
# WeatherPy

#---

## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 641

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "appid=" + weather_api_key + "&q=" + city + "&units=metric"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port-aux-francais
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | soe
# Processing Record 4 of Set 1 | vila velha
# Processing Record 5 of Set 1 | puerto natales
# Processing Record 6 of Set 1 | vladivostok
# Processing Record 7 of Set 1 | blackmans bay
# Processing Record 8 of Set 1 | edinburgh of the seven seas
# Processing Record 9 of Set 1 | vadso
# Processing Record 10 of Set 1 | adamstown
# Processing Record 11 of Set 1 | utrik
# Processing Record 12 of Set 1 | tiksi
# Processing Record 13 of Set 1 | longyearbyen
# Processing Record 14 of Set 1 | hithadhoo
# Processing Record 15 of Set 1 | georgetown
# Processing Record 16 of Set 1 | mancio lima
# Processing Record 17 of Set 1 | west island
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | dudinka
# Processing Record 20 of Set 1 | yellowknife
# Processing Record 21 of Set 1 | ribeira grande
# Processing Record 22 of Set 1 | sitka
# Processing Record 23 of Set 1 | dhidhdhoo
# Processing Record 24 of Set 1 | hamilton
# Processing Record 25 of Set 1 | tafuna
# Processing Record 26 of Set 1 | iskateley
# Processing Record 27 of Set 1 | port lincoln
# Processing Record 28 of Set 1 | college
# Processing Record 29 of Set 1 | port elizabeth
# Processing Record 30 of Set 1 | wuwei
# Processing Record 31 of Set 1 | pelabuhanratu
# Processing Record 32 of Set 1 | saint croix
# Processing Record 33 of Set 1 | chernyshevsk
# Processing Record 34 of Set 1 | san patricio
# Processing Record 35 of Set 1 | patti
# Processing Record 36 of Set 1 | beipiao
# Processing Record 37 of Set 1 | takoradi
# Processing Record 38 of Set 1 | volzhsk
# Processing Record 39 of Set 1 | coquimbo
# Processing Record 40 of Set 1 | northam
# Processing Record 41 of Set 1 | ust-nera
# Processing Record 42 of Set 1 | bethel
# Processing Record 43 of Set 1 | grytviken
# Processing Record 44 of Set 1 | thompson
# Processing Record 45 of Set 1 | zawadzkie
# Processing Record 46 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 47 of Set 1 | tralee
# Processing Record 48 of Set 1 | waitangi
# Processing Record 49 of Set 1 | cidreira
# Processing Record 50 of Set 1 | vila franca do campo
# Processing Record 0 of Set 2 | lihue
# Processing Record 1 of Set 2 | new norfolk
# Processing Record 2 of Set 2 | saipan
# Processing Record 3 of Set 2 | tashtyp
# Processing Record 4 of Set 2 | sandnessjoen
# Processing Record 5 of Set 2 | cadale
# Processing Record 6 of Set 2 | badger
# Processing Record 7 of Set 2 | yeniseysk
# Processing Record 8 of Set 2 | san rafael
# Processing Record 9 of Set 2 | lompoc
# Processing Record 10 of Set 2 | suoyarvi
# Processing Record 11 of Set 2 | santyoku
# Processing Record 12 of Set 2 | tanout
# Processing Record 13 of Set 2 | bodaybo
# Processing Record 14 of Set 2 | san antonio de pale
# Processing Record 15 of Set 2 | bilibino
# Processing Record 16 of Set 2 | cable beach
# City not found. Skipping...
# Processing Record 17 of Set 2 | mahina
# Processing Record 18 of Set 2 | bayanhongor
# Processing Record 19 of Set 2 | brookings
# Processing Record 20 of Set 2 | puerto deseado
# Processing Record 21 of Set 2 | buchanan
# Processing Record 22 of Set 2 | ha'il
# Processing Record 23 of Set 2 | iqaluit
# Processing Record 24 of Set 2 | karratha
# Processing Record 25 of Set 2 | newman
# Processing Record 26 of Set 2 | jolo
# Processing Record 27 of Set 2 | sinabang
# Processing Record 28 of Set 2 | wailua homesteads
# Processing Record 29 of Set 2 | kodiak
# Processing Record 30 of Set 2 | quepos
# Processing Record 31 of Set 2 | zelenoborskiy
# Processing Record 32 of Set 2 | quellon
# Processing Record 33 of Set 2 | mirnyy
# Processing Record 34 of Set 2 | bani walid
# Processing Record 35 of Set 2 | qandala
# Processing Record 36 of Set 2 | birine
# Processing Record 37 of Set 2 | bungu
# Processing Record 38 of Set 2 | lebu
# Processing Record 39 of Set 2 | fort bragg
# Processing Record 40 of Set 2 | canutama
# Processing Record 41 of Set 2 | owen sound
# Processing Record 42 of Set 2 | noumea
# Processing Record 43 of Set 2 | piranhas
# Processing Record 44 of Set 2 | juneau
# Processing Record 45 of Set 2 | bredasdorp
# Processing Record 46 of Set 2 | gamba
# Processing Record 47 of Set 2 | papatowai
# Processing Record 48 of Set 2 | beitbridge
# Processing Record 49 of Set 2 | viana do castelo
# Processing Record 0 of Set 3 | kavaratti
# Processing Record 1 of Set 3 | dzilam gonzalez
# Processing Record 2 of Set 3 | klaksvik
# Processing Record 3 of Set 3 | avarua
# Processing Record 4 of Set 3 | adamus
# Processing Record 5 of Set 3 | international falls
# Processing Record 6 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 7 of Set 3 | lesosibirsk
# Processing Record 8 of Set 3 | camarinas
# Processing Record 9 of Set 3 | devarkonda
# Processing Record 10 of Set 3 | ostersund
# Processing Record 11 of Set 3 | taoudenni
# Processing Record 12 of Set 3 | klyuchi
# Processing Record 13 of Set 3 | rakops
# Processing Record 14 of Set 3 | arraial do cabo
# Processing Record 15 of Set 3 | selfoss
# Processing Record 16 of Set 3 | dunedin
# Processing Record 17 of Set 3 | fale old settlement
# Processing Record 18 of Set 3 | atafu village
# Processing Record 19 of Set 3 | invercargill
# Processing Record 20 of Set 3 | hadibu
# Processing Record 21 of Set 3 | fuvahmulah
# City not found. Skipping...
# Processing Record 22 of Set 3 | hasaki
# Processing Record 23 of Set 3 | rio gallegos
# Processing Record 24 of Set 3 | isafjordur
# Processing Record 25 of Set 3 | oranjemund
# Processing Record 26 of Set 3 | cabedelo
# Processing Record 27 of Set 3 | ilulissat
# Processing Record 28 of Set 3 | bardai
# Processing Record 29 of Set 3 | chonchi
# Processing Record 30 of Set 3 | alice springs
# Processing Record 31 of Set 3 | alaghsas
# Processing Record 32 of Set 3 | charters towers
# Processing Record 33 of Set 3 | nyurba
# Processing Record 34 of Set 3 | port mathurin
# Processing Record 35 of Set 3 | puerto ayora
# Processing Record 36 of Set 3 | anadyr
# Processing Record 37 of Set 3 | penzance
# Processing Record 38 of Set 3 | lubartow
# Processing Record 39 of Set 3 | crane
# Processing Record 40 of Set 3 | whitehorse
# Processing Record 41 of Set 3 | hermanus
# Processing Record 42 of Set 3 | berdigestyakh
# Processing Record 43 of Set 3 | mariental
# Processing Record 44 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 45 of Set 3 | itoman
# Processing Record 46 of Set 3 | 'ohonua
# City not found. Skipping...
# Processing Record 47 of Set 3 | vernal
# Processing Record 48 of Set 3 | walvis bay
# Processing Record 49 of Set 3 | hawaiian paradise park
# Processing Record 0 of Set 4 | kerikeri
# Processing Record 1 of Set 4 | callaway
# Processing Record 2 of Set 4 | kamen'-rybolov
# Processing Record 3 of Set 4 | st. john's
# Processing Record 4 of Set 4 | argo
# Processing Record 5 of Set 4 | kendari
# Processing Record 6 of Set 4 | constantia
# Processing Record 7 of Set 4 | saint-felicien
# Processing Record 8 of Set 4 | ancud
# Processing Record 9 of Set 4 | nuuk
# Processing Record 10 of Set 4 | talnakh
# Processing Record 11 of Set 4 | maloye ganyushkino
# Processing Record 12 of Set 4 | bubaque
# Processing Record 13 of Set 4 | relizane
# Processing Record 14 of Set 4 | utiel
# Processing Record 15 of Set 4 | acapulco de juarez
# Processing Record 16 of Set 4 | kaintragarh
# Processing Record 17 of Set 4 | makhambet
# Processing Record 18 of Set 4 | remire-montjoly
# Processing Record 19 of Set 4 | susuman
# Processing Record 20 of Set 4 | tuam
# Processing Record 21 of Set 4 | nemuro
# Processing Record 22 of Set 4 | antsiranana
# Processing Record 23 of Set 4 | qaqortoq
# Processing Record 24 of Set 4 | vilyuchinsk
# Processing Record 25 of Set 4 | estavayer-le-lac
# Processing Record 26 of Set 4 | port glaud
# City not found. Skipping...
# Processing Record 27 of Set 4 | maintirano
# Processing Record 28 of Set 4 | saudarkrokur
# Processing Record 29 of Set 4 | enewetak
# Processing Record 30 of Set 4 | keflavik
# Processing Record 31 of Set 4 | darhan
# Processing Record 32 of Set 4 | dzhalagash
# Processing Record 33 of Set 4 | kobe
# Processing Record 34 of Set 4 | malango
# Processing Record 35 of Set 4 | kavieng
# Processing Record 36 of Set 4 | izberbash
# Processing Record 37 of Set 4 | gisborne
# Processing Record 38 of Set 4 | ribnitz-damgarten
# Processing Record 39 of Set 4 | mariehamn
# Processing Record 40 of Set 4 | krasnoturansk
# Processing Record 41 of Set 4 | baranovichi
# Processing Record 42 of Set 4 | las varillas
# Processing Record 43 of Set 4 | i-n-salah
# Processing Record 44 of Set 4 | mococa
# Processing Record 45 of Set 4 | carnarvon
# Processing Record 46 of Set 4 | ankang
# Processing Record 47 of Set 4 | lashio
# Processing Record 48 of Set 4 | vorgashor
# Processing Record 49 of Set 4 | vershino-darasunskiy
# Processing Record 0 of Set 5 | las khorey
# Processing Record 1 of Set 5 | kamyshevatskaya
# Processing Record 2 of Set 5 | nova sintra
# Processing Record 3 of Set 5 | saint-francois
# Processing Record 4 of Set 5 | santa catarina juquila
# Processing Record 5 of Set 5 | margaret river
# Processing Record 6 of Set 5 | westport
# Processing Record 7 of Set 5 | maragogi
# Processing Record 8 of Set 5 | mata-utu
# Processing Record 9 of Set 5 | verkhnevilyuysk
# Processing Record 10 of Set 5 | afaahiti
# Processing Record 11 of Set 5 | boali
# Processing Record 12 of Set 5 | olonkinbyen
# Processing Record 13 of Set 5 | zarautz
# Processing Record 14 of Set 5 | zarzis
# Processing Record 15 of Set 5 | divnomorskoye
# Processing Record 16 of Set 5 | filipstad
# Processing Record 17 of Set 5 | andergrove
# Processing Record 18 of Set 5 | impfondo
# Processing Record 19 of Set 5 | shuangyang
# Processing Record 20 of Set 5 | jamestown
# Processing Record 21 of Set 5 | melekeok village
# Processing Record 22 of Set 5 | jining
# Processing Record 23 of Set 5 | cabo san lucas
# Processing Record 24 of Set 5 | tabas
# Processing Record 25 of Set 5 | timimoun
# Processing Record 26 of Set 5 | harstad
# Processing Record 27 of Set 5 | kanel
# Processing Record 28 of Set 5 | cat ba
# City not found. Skipping...
# Processing Record 29 of Set 5 | callao
# Processing Record 30 of Set 5 | behat
# Processing Record 31 of Set 5 | eraan
# Processing Record 32 of Set 5 | blair
# Processing Record 33 of Set 5 | toga village
# City not found. Skipping...
# Processing Record 34 of Set 5 | mar del plata
# Processing Record 35 of Set 5 | lubang
# Processing Record 36 of Set 5 | colonia
# Processing Record 37 of Set 5 | port alfred
# Processing Record 38 of Set 5 | umba
# Processing Record 39 of Set 5 | sishilichengzi
# City not found. Skipping...
# Processing Record 40 of Set 5 | egilsstadir
# Processing Record 41 of Set 5 | bac lieu
# Processing Record 42 of Set 5 | gryazi
# Processing Record 43 of Set 5 | pontes e lacerda
# Processing Record 44 of Set 5 | bargara
# City not found. Skipping...
# Processing Record 45 of Set 5 | hafar al-batin
# Processing Record 46 of Set 5 | tokar
# Processing Record 47 of Set 5 | kolonia town
# Processing Record 48 of Set 5 | navia
# Processing Record 49 of Set 5 | guanica
# Processing Record 0 of Set 6 | yur'yevets
# Processing Record 1 of Set 6 | salekhard
# Processing Record 2 of Set 6 | lagos
# Processing Record 3 of Set 6 | papao
# Processing Record 4 of Set 6 | ketchikan
# Processing Record 5 of Set 6 | opuwo
# Processing Record 6 of Set 6 | koneurgench
# City not found. Skipping...
# Processing Record 7 of Set 6 | yulinshi
# Processing Record 8 of Set 6 | sao jose da coroa grande
# Processing Record 9 of Set 6 | kataragama
# City not found. Skipping...
# Processing Record 10 of Set 6 | zhashkiv
# Processing Record 11 of Set 6 | lishu
# Processing Record 12 of Set 6 | stavanger
# Processing Record 13 of Set 6 | sidi ifni
# Processing Record 14 of Set 6 | nagqu
# Processing Record 15 of Set 6 | hobyo
# Processing Record 16 of Set 6 | stanley
# Processing Record 17 of Set 6 | yevlakh
# Processing Record 18 of Set 6 | saint-philippe
# Processing Record 19 of Set 6 | mount pearl
# Processing Record 20 of Set 6 | baardheere
# Processing Record 21 of Set 6 | borba
# Processing Record 22 of Set 6 | castillos
# Processing Record 23 of Set 6 | portland
# Processing Record 24 of Set 6 | mountain home
# Processing Record 25 of Set 6 | piti village
# Processing Record 26 of Set 6 | yashkul'
# Processing Record 27 of Set 6 | katsuren-haebaru
# Processing Record 28 of Set 6 | gurupa
# Processing Record 29 of Set 6 | palmer
# Processing Record 30 of Set 6 | imbituba
# Processing Record 31 of Set 6 | micheweni
# Processing Record 32 of Set 6 | olofstrom
# City not found. Skipping...
# Processing Record 33 of Set 6 | fuyuan
# Processing Record 34 of Set 6 | fredericton
# Processing Record 35 of Set 6 | trevelin
# Processing Record 36 of Set 6 | grain valley
# Processing Record 37 of Set 6 | geraldton
# Processing Record 38 of Set 6 | coahuayana de hidalgo
# Processing Record 39 of Set 6 | aasiaat
# Processing Record 40 of Set 6 | sabha
# Processing Record 41 of Set 6 | la passe
# Processing Record 42 of Set 6 | praia da vitoria
# Processing Record 43 of Set 6 | punta gorda
# Processing Record 44 of Set 6 | codrington
# Processing Record 45 of Set 6 | dryden
# Processing Record 46 of Set 6 | fortuna
# Processing Record 47 of Set 6 | launceston
# Processing Record 48 of Set 6 | bijie
# Processing Record 49 of Set 6 | bismarck
# Processing Record 0 of Set 7 | punta arenas
# Processing Record 1 of Set 7 | tieling
# Processing Record 2 of Set 7 | luang namtha
# Processing Record 3 of Set 7 | cheremushki
# Processing Record 4 of Set 7 | cooper's town
# Processing Record 5 of Set 7 | petropavlovsk-kamchatsky
# Processing Record 6 of Set 7 | tubmanburg
# Processing Record 7 of Set 7 | ursulo galvan
# Processing Record 8 of Set 7 | howard springs
# Processing Record 9 of Set 7 | villa de costa rica
# Processing Record 10 of Set 7 | isangel
# Processing Record 11 of Set 7 | ordynskoye
# Processing Record 12 of Set 7 | ystad
# Processing Record 13 of Set 7 | thunder bay
# Processing Record 14 of Set 7 | tefe
# Processing Record 15 of Set 7 | jumla
# Processing Record 16 of Set 7 | el tarf
# Processing Record 17 of Set 7 | mount isa
# Processing Record 18 of Set 7 | trairi
# Processing Record 19 of Set 7 | ceres
# Processing Record 20 of Set 7 | puerto baquerizo moreno
# Processing Record 21 of Set 7 | uvira
# Processing Record 22 of Set 7 | uray
# Processing Record 23 of Set 7 | china
# Processing Record 24 of Set 7 | ingeniero jacobacci
# Processing Record 25 of Set 7 | selkirk
# Processing Record 26 of Set 7 | rio grande
# Processing Record 27 of Set 7 | ulladulla
# Processing Record 28 of Set 7 | ar ruways
# Processing Record 29 of Set 7 | yilan
# Processing Record 30 of Set 7 | palasa
# Processing Record 31 of Set 7 | kone
# Processing Record 32 of Set 7 | mammoth lakes
# Processing Record 33 of Set 7 | nichinan
# Processing Record 34 of Set 7 | korsakov
# Processing Record 35 of Set 7 | shalkar
# Processing Record 36 of Set 7 | kingston
# Processing Record 37 of Set 7 | ust'-kulom
# Processing Record 38 of Set 7 | prainha
# Processing Record 39 of Set 7 | kapa'a
# Processing Record 40 of Set 7 | yung shue wan
# Processing Record 41 of Set 7 | sosnovskoye
# Processing Record 42 of Set 7 | vilyuysk
# Processing Record 43 of Set 7 | espargos
# City not found. Skipping...
# Processing Record 44 of Set 7 | severo-yeniseyskiy
# Processing Record 45 of Set 7 | chibougamau
# Processing Record 46 of Set 7 | pisco
# Processing Record 47 of Set 7 | ingeniero guillermo n. juarez
# Processing Record 48 of Set 7 | lame
# Processing Record 49 of Set 7 | bengkulu
# Processing Record 0 of Set 8 | prince albert
# Processing Record 1 of Set 8 | pizarro
# Processing Record 2 of Set 8 | gulf shores
# Processing Record 3 of Set 8 | yamba
# Processing Record 4 of Set 8 | norilsk
# Processing Record 5 of Set 8 | lata
# Processing Record 6 of Set 8 | szczebrzeszyn
# Processing Record 7 of Set 8 | zayed city
# Processing Record 8 of Set 8 | bahia honda
# Processing Record 9 of Set 8 | sur
# Processing Record 10 of Set 8 | santa eularia des riu
# Processing Record 11 of Set 8 | daru
# Processing Record 12 of Set 8 | namdrik
# Processing Record 13 of Set 8 | tomatlan
# Processing Record 14 of Set 8 | taroa
# Processing Record 15 of Set 8 | yelizovo
# Processing Record 16 of Set 8 | port alberni
# City not found. Skipping...
# Processing Record 17 of Set 8 | sisimiut
# City not found. Skipping...
# Processing Record 18 of Set 8 | painesville
# City not found. Skipping...
# Processing Record 19 of Set 8 | srivardhan
# Processing Record 20 of Set 8 | hammerfest
# Processing Record 21 of Set 8 | howrah
# Processing Record 22 of Set 8 | vendas novas
# Processing Record 23 of Set 8 | arfoud
# Processing Record 24 of Set 8 | antofagasta
# Processing Record 25 of Set 8 | gizo
# Processing Record 26 of Set 8 | chilecito
# Processing Record 27 of Set 8 | labrador city
# Processing Record 28 of Set 8 | gwangju
# Processing Record 29 of Set 8 | cherdyn'
# Processing Record 30 of Set 8 | devinuwara
# City not found. Skipping...
# Processing Record 31 of Set 8 | yarmouth
# Processing Record 32 of Set 8 | vanino
# Processing Record 33 of Set 8 | solwezi
# Processing Record 34 of Set 8 | khorixas
# Processing Record 35 of Set 8 | weno
# Processing Record 36 of Set 8 | neiafu
# Processing Record 37 of Set 8 | mount gambier
# Processing Record 38 of Set 8 | dubrovnik
# Processing Record 39 of Set 8 | greymouth
# Processing Record 40 of Set 8 | rice lake
# Processing Record 41 of Set 8 | whangarei
# Processing Record 42 of Set 8 | turkmenbasy
# Processing Record 43 of Set 8 | quelimane
# Processing Record 44 of Set 8 | prien
# Processing Record 45 of Set 8 | kurayyimah
# Processing Record 46 of Set 8 | evanston
# Processing Record 47 of Set 8 | berezovyy
# Processing Record 48 of Set 8 | pariaman
# Processing Record 49 of Set 8 | as sulayyil
# Processing Record 0 of Set 9 | nieuw amsterdam
# Processing Record 1 of Set 9 | luderitz
# Processing Record 2 of Set 9 | moroni
# Processing Record 3 of Set 9 | ermelo
# Processing Record 4 of Set 9 | aykhal
# Processing Record 5 of Set 9 | palapag
# Processing Record 6 of Set 9 | ramadi
# Processing Record 7 of Set 9 | patna
# Processing Record 8 of Set 9 | kawambwa
# Processing Record 9 of Set 9 | kristiansund
# Processing Record 10 of Set 9 | palma sola
# Processing Record 11 of Set 9 | beau vallon
# Processing Record 12 of Set 9 | dem'yanovo
# Processing Record 13 of Set 9 | olinda
# Processing Record 14 of Set 9 | bamboo flat
# Processing Record 15 of Set 9 | dickinson
# Processing Record 16 of Set 9 | alto araguaia
# Processing Record 17 of Set 9 | santana do matos
# Processing Record 18 of Set 9 | tot'ma
# Processing Record 19 of Set 9 | malabar
# Processing Record 20 of Set 9 | alamosa
# Processing Record 21 of Set 9 | luimneach
# Processing Record 22 of Set 9 | trinidad
# Processing Record 23 of Set 9 | banlung
# Processing Record 24 of Set 9 | springs
# Processing Record 25 of Set 9 | flying fish cove
# Processing Record 26 of Set 9 | tutong
# Processing Record 27 of Set 9 | yarmolyntsi
# Processing Record 28 of Set 9 | chicoana
# Processing Record 29 of Set 9 | carl junction
# Processing Record 30 of Set 9 | hirara
# Processing Record 31 of Set 9 | santana
# Processing Record 32 of Set 9 | bastia
# Processing Record 33 of Set 9 | queenstown
# Processing Record 34 of Set 9 | siwa oasis
# Processing Record 35 of Set 9 | casimiro de abreu
# Processing Record 36 of Set 9 | conde
# Processing Record 37 of Set 9 | weatherford
# Processing Record 38 of Set 9 | lokken
# City not found. Skipping...
# Processing Record 39 of Set 9 | la foa
# Processing Record 40 of Set 9 | tura
# Processing Record 41 of Set 9 | muzayri'
# City not found. Skipping...
# Processing Record 42 of Set 9 | kalmunai
# Processing Record 43 of Set 9 | sinfra
# Processing Record 44 of Set 9 | yaren
# Processing Record 45 of Set 9 | posto fiscal rolim de moura
# Processing Record 46 of Set 9 | dwarka
# Processing Record 47 of Set 9 | nowa sol
# Processing Record 48 of Set 9 | kailua-kona
# Processing Record 49 of Set 9 | dongola
# Processing Record 0 of Set 10 | minas de marcona
# Processing Record 1 of Set 10 | anibare
# City not found. Skipping...
# Processing Record 2 of Set 10 | broken hill
# Processing Record 3 of Set 10 | tutoia
# Processing Record 4 of Set 10 | pekanbaru
# Processing Record 5 of Set 10 | sonsorol village
# City not found. Skipping...
# Processing Record 6 of Set 10 | udachny
# Processing Record 7 of Set 10 | ta`u
# Processing Record 8 of Set 10 | uturoa
# Processing Record 9 of Set 10 | buka
# Processing Record 10 of Set 10 | holualoa
# Processing Record 11 of Set 10 | cannonvale
# Processing Record 12 of Set 10 | baymak
# Processing Record 13 of Set 10 | akureyri
# Processing Record 14 of Set 10 | gowurdak
# Processing Record 15 of Set 10 | khanty-mansiysk
# Processing Record 16 of Set 10 | nezhinka
# Processing Record 17 of Set 10 | ballina
# Processing Record 18 of Set 10 | laojunmiao
# Processing Record 19 of Set 10 | ekibastuz
# Processing Record 20 of Set 10 | aden
# Processing Record 21 of Set 10 | tazovsky
# Processing Record 22 of Set 10 | bousso
# Processing Record 23 of Set 10 | puerto san carlos
# City not found. Skipping...
# Processing Record 24 of Set 10 | kalevala
# Processing Record 25 of Set 10 | chechelnyk
# Processing Record 26 of Set 10 | el granada
# Processing Record 27 of Set 10 | ceelbuur
# Processing Record 28 of Set 10 | broome
# Processing Record 29 of Set 10 | kisangani
# Processing Record 30 of Set 10 | chilca
# Processing Record 31 of Set 10 | paradip garh
# Processing Record 32 of Set 10 | sigli
# Processing Record 33 of Set 10 | great bend
# Processing Record 34 of Set 10 | kegen
# Processing Record 35 of Set 10 | winnemucca
# Processing Record 36 of Set 10 | gubkinskiy
# Processing Record 37 of Set 10 | mhamid
# Processing Record 38 of Set 10 | kangavar
# Processing Record 39 of Set 10 | sofifi
# City not found. Skipping...
# Processing Record 40 of Set 10 | tsiombe
# Processing Record 41 of Set 10 | guerrero negro
# Processing Record 42 of Set 10 | yagry
# City not found. Skipping...
# Processing Record 43 of Set 10 | palikir - national government center
# Processing Record 44 of Set 10 | bima
# Processing Record 45 of Set 10 | soroti
# Processing Record 46 of Set 10 | malpica
# Processing Record 47 of Set 10 | lautoka
# Processing Record 48 of Set 10 | paita
# Processing Record 49 of Set 10 | pichucalco
# Processing Record 0 of Set 11 | porto torres
# Processing Record 1 of Set 11 | arroyo
# Processing Record 2 of Set 11 | kourou
# Processing Record 3 of Set 11 | saratamata
# City not found. Skipping...
# Processing Record 4 of Set 11 | nishinoomote
# Processing Record 5 of Set 11 | trondheim
# Processing Record 6 of Set 11 | vingt cinq
# City not found. Skipping...
# Processing Record 7 of Set 11 | kassala
# Processing Record 8 of Set 11 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 9 of Set 11 | najran
# Processing Record 10 of Set 11 | manay
# Processing Record 11 of Set 11 | neyshabur
# Processing Record 12 of Set 11 | acarau
# Processing Record 13 of Set 11 | revda
# Processing Record 14 of Set 11 | nongstoin
# Processing Record 15 of Set 11 | burang
# Processing Record 16 of Set 11 | kyzyl-suu
# Processing Record 17 of Set 11 | tirebolu
# Processing Record 18 of Set 11 | morant bay
# Processing Record 19 of Set 11 | ahau
# City not found. Skipping...
# Processing Record 20 of Set 11 | mermoz boabab
# Processing Record 21 of Set 11 | battagram
# Processing Record 22 of Set 11 | laguna
# Processing Record 23 of Set 11 | egersund
# Processing Record 24 of Set 11 | atherton
# Processing Record 25 of Set 11 | mlimba
# Processing Record 26 of Set 11 | porbandar
# Processing Record 27 of Set 11 | tangalle
# Processing Record 28 of Set 11 | pegnitz
# Processing Record 29 of Set 11 | abou el hassan
# Processing Record 30 of Set 11 | banda aceh
# Processing Record 31 of Set 11 | bandarbeyla
# Processing Record 32 of Set 11 | mokhsogollokh
# Processing Record 33 of Set 11 | ammi moussa
# Processing Record 34 of Set 11 | grand falls-windsor
# Processing Record 35 of Set 11 | yangor
# City not found. Skipping...
# Processing Record 36 of Set 11 | jindabyne
# Processing Record 37 of Set 11 | lerwick
# Processing Record 38 of Set 11 | nelson bay
# Processing Record 39 of Set 11 | port hedland
# Processing Record 40 of Set 11 | conduaga
# Processing Record 41 of Set 11 | nema
# Processing Record 42 of Set 11 | belyy yar
# Processing Record 43 of Set 11 | roses
# Processing Record 44 of Set 11 | porto novo
# Processing Record 45 of Set 11 | san andros
# City not found. Skipping...
# Processing Record 46 of Set 11 | perechyn
# Processing Record 47 of Set 11 | pereiaslav-khmelnytskyi
# Processing Record 48 of Set 11 | alaminos
# Processing Record 49 of Set 11 | wewak
# Processing Record 0 of Set 12 | hami
# Processing Record 1 of Set 12 | las terrenas
# Processing Record 2 of Set 12 | houlton
# Processing Record 3 of Set 12 | wenchang
# Processing Record 4 of Set 12 | port-gentil
# Processing Record 5 of Set 12 | ntossoni
# City not found. Skipping...
# Processing Record 6 of Set 12 | thinadhoo
# Processing Record 7 of Set 12 | rongelap
# Processing Record 8 of Set 12 | gadzhiyevo
# Processing Record 9 of Set 12 | alo
# Processing Record 10 of Set 12 | kenai
# Processing Record 11 of Set 12 | shakawe
# Processing Record 12 of Set 12 | naracoorte
# Processing Record 13 of Set 12 | boone
# Processing Record 14 of Set 12 | viet tri
# Processing Record 15 of Set 12 | tyukhtet
# Processing Record 16 of Set 12 | banamba
# Processing Record 17 of Set 12 | qamdo
# Processing Record 18 of Set 12 | christchurch
# Processing Record 19 of Set 12 | yallahs
# Processing Record 20 of Set 12 | lovington
# Processing Record 21 of Set 12 | alvaraes
# Processing Record 22 of Set 12 | winejok
# City not found. Skipping...
# Processing Record 23 of Set 12 | tranovaho
# City not found. Skipping...
# Processing Record 24 of Set 12 | essaouira
# Processing Record 25 of Set 12 | tommot
# Processing Record 26 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 27 of Set 12 | rundu
# Processing Record 28 of Set 12 | fort st. john
# Processing Record 29 of Set 12 | lazaro cardenas
# Processing Record 30 of Set 12 | island harbour
# Processing Record 31 of Set 12 | glace bay
# Processing Record 32 of Set 12 | east london
# Processing Record 33 of Set 12 | crucecita
# Processing Record 34 of Set 12 | ormara
# Processing Record 35 of Set 12 | abeche
# Processing Record 36 of Set 12 | tambura
# Processing Record 37 of Set 12 | khromtau
# Processing Record 38 of Set 12 | ikwiriri
# Processing Record 39 of Set 12 | san francisco de la paz
# Processing Record 40 of Set 12 | fengxiang
# Processing Record 41 of Set 12 | anqing
# Processing Record 42 of Set 12 | vedea
# Processing Record 43 of Set 12 | new plymouth
# Processing Record 44 of Set 12 | urengoy
# Processing Record 45 of Set 12 | at-bashi
# Processing Record 46 of Set 12 | puerto colombia
# Processing Record 47 of Set 12 | labytnangi
# Processing Record 48 of Set 12 | nkurenkuru
# City not found. Skipping...
# Processing Record 49 of Set 12 | haiku-pauwela
# Processing Record 0 of Set 13 | kiunga
# Processing Record 1 of Set 13 | puerto leguizamo
# Processing Record 2 of Set 13 | kaele
# Processing Record 3 of Set 13 | juegang
# Processing Record 4 of Set 13 | dalbandin
# Processing Record 5 of Set 13 | mufumbwe
# Processing Record 6 of Set 13 | cuito
# Processing Record 7 of Set 13 | santiago de cao
# Processing Record 8 of Set 13 | saldanha
# Processing Record 9 of Set 13 | markaz-e hukumat-e darweshan
# Processing Record 10 of Set 13 | ouadda
# Processing Record 11 of Set 13 | potosi
# Processing Record 12 of Set 13 | usinsk
# Processing Record 13 of Set 13 | ubari
# Processing Record 14 of Set 13 | inarajan village
# Processing Record 15 of Set 13 | sake
# Processing Record 16 of Set 13 | ugoofaaru
# Processing Record 17 of Set 13 | puerto lempira
# Processing Record 18 of Set 13 | sovetsk
# Processing Record 19 of Set 13 | al mahwit
# Processing Record 20 of Set 13 | glendive
# Processing Record 21 of Set 13 | ar rutbah
# Processing Record 22 of Set 13 | ertil'
# Processing Record 23 of Set 13 | semirara
# Processing Record 24 of Set 13 | morehead city
# Processing Record 25 of Set 13 | patnongon
# Processing Record 26 of Set 13 | puerto cabezas
# Processing Record 27 of Set 13 | mossel bay
# Processing Record 28 of Set 13 | lakota
# Processing Record 29 of Set 13 | burutu
# Processing Record 30 of Set 13 | alofi
# Processing Record 31 of Set 13 | nis
# Processing Record 32 of Set 13 | tanjung pandan
# Processing Record 33 of Set 13 | pirgaaj
# Processing Record 34 of Set 13 | san pedro de cajas
# Processing Record 35 of Set 13 | arendal
# Processing Record 36 of Set 13 | yichang
# Processing Record 37 of Set 13 | arkhangel'sk
# Processing Record 38 of Set 13 | port saint john's
# Processing Record 39 of Set 13 | porto velho
# Processing Record 40 of Set 13 | prado
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_weather
# Out:
# {'coord': {'lon': -39.2208, 'lat': -17.3411},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 24.35,
#   'feels_like': 24.9,
#   'temp_min': 24.35,
#   'temp_max': 24.35,
#   'pressure': 1015,
#   'humidity': 79,
#   'sea_level': 1015,
#   'grnd_level': 1014},
#  'visibility': 10000,
#  'wind': {'speed': 3.83, 'deg': 62, 'gust': 7.46},
#  'clouds': {'all': 0},
#  'dt': 1699564171,
#  'sys': {'country': 'BR', 'sunrise': 1699516526, 'sunset': 1699562760},
#  'timezone': -10800,
#  'id': 3452483,
#  'name': 'Prado',
#  'cod': 200}

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df

# Show Record Count
city_data_df.count()
# Out:
# City          604
# Lat           604
# Lng           604
# Max Temp      604
# Humidity      604
# Cloudiness    604
# Wind Speed    604
# Country       604
# Date          604
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  port-aux-francais -49.3500   70.2167      5.37        94         100
# 1             albany  42.6001  -73.9662      9.65        81         100
# 2                soe  -9.8607  124.2840     19.05        71           8
# 3         vila velha -20.3297  -40.2925     26.97        69           0
# 4     puerto natales -51.7236  -72.4875     13.25        38          20
#
#    Wind Speed Country        Date
# 0       11.38      TF  1699563906
# 1        0.45      US  1699563326
# 2        1.37      ID  1699563907
# 3        8.75      BR  1699563644
# 4       15.43      CL  1699563675

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        port-aux-francais -49.3500   70.2167      5.37        94         100
# 1                   albany  42.6001  -73.9662      9.65        81         100
# 2                      soe  -9.8607  124.2840     19.05        71           8
# 3               vila velha -20.3297  -40.2925     26.97        69           0
# 4           puerto natales -51.7236  -72.4875     13.25        38          20
#
#          Wind Speed Country        Date
# City_ID
# 0             11.38      TF  1699563906
# 1              0.45      US  1699563326
# 2              1.37      ID  1699563907
# 3              8.75      BR  1699563644
# 4             15.43      CL  1699563675

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_values = city_data_df['Lat']
y_values = city_data_df['Max Temp']
plt.scatter(x_values,y_values,marker="o",facecolors='blue',edgecolors='black',)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.grid(True)

# Incorporate the other graph properties
plt.title('City Latitude vs Max Temperature (2023-11-9)')

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_values = city_data_df['Lat']
y_values = city_data_df['Humidity']
plt.scatter(x_values,y_values,marker="o",facecolors='blue',edgecolors='black',)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)

# Incorporate the other graph properties
plt.title('City Latitude vs Humidity (2023-11-9)')

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_values = city_data_df['Lat']
y_values = city_data_df['Cloudiness']
plt.scatter(x_values,y_values,marker="o",facecolors='blue',edgecolors='black',)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)

# Incorporate the other graph properties
plt.title('City Latitude vs Cloudiness (2023-11-9)')

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_values = city_data_df['Lat']
y_values = city_data_df['Wind Speed']
plt.scatter(x_values,y_values,marker="o",facecolors='blue',edgecolors='black',)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.grid(True)


# Incorporate the other graph properties
plt.title('City Latitude vs Wind Speed (2023-11-9)')

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linearRegression(x_values,y_values, regEQplotX, regEQplotY, ylabel):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values, marker="o", facecolors="blue")
    plt.plot(x_values,regress_values,"r-", linewidth=3)
    plt.grid(True)
    print(f'The r-value is {rvalue}')
    plt.annotate(line_eq,(regEQplotX,regEQplotY),color="red")
    plt.xlabel('Latitude')
    plt.ylabel(f'{ylabel}')
    plt.grid()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)city_data_df
northern_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]).astype(float)>= 0, :]
northern_hemi_df
# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1             albany  42.6001  -73.9662      9.65        81         100
# 5        vladivostok  43.1056  131.8735     -3.32        63          21
# 8              vadso  70.0744   29.7487     -1.91        86          75
# 10             utrik  11.2278  169.8474     27.70        74          95
# 11             tiksi  71.6872  128.8694    -16.03        87         100
#
#          Wind Speed Country        Date
# City_ID
# 1              0.45      US  1699563326
# 5              7.80      RU  1699563908
# 8              8.75      NO  1699563909
# 10            10.29      MH  1699563836
# 11             6.58      RU  1699563882

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]).astype(float)< 0, :]
southern_hemi_df

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        port-aux-francais -49.3500   70.2167      5.37        94         100
# 2                      soe  -9.8607  124.2840     19.05        71           8
# 3               vila velha -20.3297  -40.2925     26.97        69           0
# 4           puerto natales -51.7236  -72.4875     13.25        38          20
# 6            blackmans bay -43.0167  147.3167     15.07        95          31
#
#          Wind Speed Country        Date
# City_ID
# 0             11.38      TF  1699563906
# 2              1.37      ID  1699563907
# 3              8.75      BR  1699563644
# 4             15.43      CL  1699563675
# 6              0.45      AU  1699563908

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_plot = northern_hemi_df["Lat"]
y_plot = northern_hemi_df["Max Temp"]
linearRegression(x_plot, y_plot, 5, -20, "Temperature (C)")
plt.savefig("output_data/Fig5.png",dpi=300, bbox_inches = "tight")
# Out:
# The r-value is -0.8363515314194623

# %%
# Linear regression on Southern Hemisphere
x_plot = southern_hemi_df["Lat"]
y_plot = southern_hemi_df["Max Temp"]
linearRegression(x_plot, y_plot, -55, 35, "Temperature (C)")
plt.savefig("output_data/Fig6.png",dpi=300, bbox_inches = "tight")
# Out:
# The r-value is 0.7038933713426537

# %% [markdown]
# Discussion about the linear relationship:
# Latitude vs Temperature - As expected, the farther away from the equator we travel, the max temperature is lower.  Both r-values are high enough to show that there is a correlation.  The r-value correlation is slightly higher in the northern hemisphere.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_plot = northern_hemi_df["Lat"]
y_plot = northern_hemi_df["Humidity"]
linearRegression(x_plot, y_plot, 50, 20, "Humidity (%)")
plt.savefig("output_data/Fig7.png",dpi=300, bbox_inches = "tight")
# Out:
# The r-value is 0.24394138424703662

# %%
# Southern Hemisphere
x_plot = southern_hemi_df["Lat"]
y_plot = southern_hemi_df["Humidity"]
linearRegression(x_plot, y_plot, -15, 10, "Humidity (%)")
plt.savefig("output_data/Fig8.png",dpi=300, bbox_inches = "tight")
# Out:
# The r-value is 0.2691336045194775

# %% [markdown]
# Discussion about the linear relationship:
# According to the data, there is no correlation of the level of humidity compared to the distance from the equator.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_plot = northern_hemi_df["Lat"]
y_plot = northern_hemi_df["Cloudiness"]
linearRegression(x_plot, y_plot, 50, 10, "Cloudiness (%)")
plt.savefig("output_data/Fig7.png",dpi=300, bbox_inches = "tight")
# Out:
# The r-value is 0.17436033353145547

# %%
# Southern Hemisphere
x_plot = southern_hemi_df["Lat"]
y_plot = southern_hemi_df["Cloudiness"]
linearRegression(x_plot, y_plot, -50, 50, "Cloudiness (%)")
plt.savefig("output_data/Fig7.png",dpi=300, bbox_inches = "tight")
# Out:
# The r-value is 0.2006795072966712

# %% [markdown]
# Discussion about the linear relationship:
# There is a slightly higher correlation in the southern atmosphere.  But there is still no significant correlation between cloudiness and distance from the equator.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_plot = northern_hemi_df["Lat"]
y_plot = northern_hemi_df["Wind Speed"]
linearRegression(x_plot, y_plot, 50, 15, "Wind Speed (m/s)")
plt.savefig("output_data/Fig7.png",dpi=300, bbox_inches = "tight")
# Out:
# The r-value is 0.14971295903829562

# %%
# Southern Hemisphere
x_plot = southern_hemi_df["Lat"]
y_plot = southern_hemi_df["Wind Speed"]
linearRegression(x_plot, y_plot, -50, 10, "Wind Speed (m/s)")
plt.savefig("output_data/Fig7.png",dpi=300, bbox_inches = "tight")
# Out:
# The r-value is -0.101520493461326

# %% [markdown]
# Discussion about the linear relationship:
# According to the data, there is no correlation of the level of humidity compared to the distance from the equator.
