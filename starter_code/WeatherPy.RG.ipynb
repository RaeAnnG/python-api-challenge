# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 605

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "appid=" + weather_api_key + "&q=" + city + "&units=metric"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lat"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sinop
# Processing Record 2 of Set 1 | tangalle
# Processing Record 3 of Set 1 | thompson
# Processing Record 4 of Set 1 | kyren
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | iqaluit
# Processing Record 7 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 8 of Set 1 | puerto natales
# Processing Record 9 of Set 1 | berezovyy
# Processing Record 10 of Set 1 | waseca
# Processing Record 11 of Set 1 | invercargill
# Processing Record 12 of Set 1 | fale old settlement
# Processing Record 13 of Set 1 | avarua
# Processing Record 14 of Set 1 | santa maria del oro
# Processing Record 15 of Set 1 | bredasdorp
# Processing Record 16 of Set 1 | yellowknife
# Processing Record 17 of Set 1 | waitangi
# Processing Record 18 of Set 1 | baise city
# Processing Record 19 of Set 1 | port-aux-francais
# Processing Record 20 of Set 1 | new norfolk
# Processing Record 21 of Set 1 | guerrero negro
# Processing Record 22 of Set 1 | port alfred
# Processing Record 23 of Set 1 | bilibino
# Processing Record 24 of Set 1 | bethel
# Processing Record 25 of Set 1 | tumayr
# Processing Record 26 of Set 1 | ribeira grande
# Processing Record 27 of Set 1 | les cayes
# Processing Record 28 of Set 1 | wildberg
# Processing Record 29 of Set 1 | kartaly
# Processing Record 30 of Set 1 | huatabampo
# Processing Record 31 of Set 1 | adamstown
# Processing Record 32 of Set 1 | tevriz
# Processing Record 33 of Set 1 | edinburgh of the seven seas
# Processing Record 34 of Set 1 | antsiranana
# Processing Record 35 of Set 1 | grytviken
# Processing Record 36 of Set 1 | nar'yan-mar
# Processing Record 37 of Set 1 | hawaiian paradise park
# Processing Record 38 of Set 1 | happy valley-goose bay
# Processing Record 39 of Set 1 | margaret river
# Processing Record 40 of Set 1 | qaqortoq
# Processing Record 41 of Set 1 | kerikeri
# Processing Record 42 of Set 1 | el calafate
# Processing Record 43 of Set 1 | whitehorse
# Processing Record 44 of Set 1 | ilulissat
# Processing Record 45 of Set 1 | coquimbo
# Processing Record 46 of Set 1 | hermanus
# Processing Record 47 of Set 1 | axim
# Processing Record 48 of Set 1 | blackmans bay
# Processing Record 49 of Set 1 | lata
# Processing Record 50 of Set 1 | bochum
# Processing Record 0 of Set 2 | hamilton
# Processing Record 1 of Set 2 | nuuk
# Processing Record 2 of Set 2 | olonkinbyen
# Processing Record 3 of Set 2 | stanley
# Processing Record 4 of Set 2 | ust-nera
# Processing Record 5 of Set 2 | pyt-yakh
# Processing Record 6 of Set 2 | albany
# Processing Record 7 of Set 2 | salinopolis
# Processing Record 8 of Set 2 | port mathurin
# Processing Record 9 of Set 2 | anadyr
# Processing Record 10 of Set 2 | wailua homesteads
# Processing Record 11 of Set 2 | lorengau
# Processing Record 12 of Set 2 | tiksi
# Processing Record 13 of Set 2 | newman
# Processing Record 14 of Set 2 | constantia
# Processing Record 15 of Set 2 | macapa
# Processing Record 16 of Set 2 | tiznit
# Processing Record 17 of Set 2 | nova sintra
# Processing Record 18 of Set 2 | killeen
# Processing Record 19 of Set 2 | puerto ayora
# Processing Record 20 of Set 2 | khanty-mansiysk
# Processing Record 21 of Set 2 | amursk
# Processing Record 22 of Set 2 | klyuchi
# Processing Record 23 of Set 2 | tazacorte
# Processing Record 24 of Set 2 | hayma'
# City not found. Skipping...
# Processing Record 25 of Set 2 | xixiang
# Processing Record 26 of Set 2 | rio grande
# Processing Record 27 of Set 2 | labrador city
# Processing Record 28 of Set 2 | san patricio
# Processing Record 29 of Set 2 | verkhniy rohachyk
# Processing Record 30 of Set 2 | west island
# Processing Record 31 of Set 2 | san luis de la loma
# Processing Record 32 of Set 2 | prince rupert
# Processing Record 33 of Set 2 | pundong
# Processing Record 34 of Set 2 | shani
# Processing Record 35 of Set 2 | karratha
# Processing Record 36 of Set 2 | afaahiti
# Processing Record 37 of Set 2 | peace river
# Processing Record 38 of Set 2 | kralendijk
# Processing Record 39 of Set 2 | robertsport
# Processing Record 40 of Set 2 | touros
# Processing Record 41 of Set 2 | uturoa
# Processing Record 42 of Set 2 | sinabang
# Processing Record 43 of Set 2 | grand falls-windsor
# Processing Record 44 of Set 2 | san antonio de pale
# Processing Record 45 of Set 2 | east london
# Processing Record 46 of Set 2 | tanout
# Processing Record 47 of Set 2 | kumeny
# Processing Record 48 of Set 2 | dover
# Processing Record 49 of Set 2 | 'ohonua
# City not found. Skipping...
# Processing Record 0 of Set 3 | pacific grove
# Processing Record 1 of Set 3 | utrik
# Processing Record 2 of Set 3 | kavaratti
# Processing Record 3 of Set 3 | margate
# Processing Record 4 of Set 3 | tidjikja
# Processing Record 5 of Set 3 | birnin kebbi
# Processing Record 6 of Set 3 | burao
# Processing Record 7 of Set 3 | pangai
# Processing Record 8 of Set 3 | isafjordur
# Processing Record 9 of Set 3 | pilibangan
# Processing Record 10 of Set 3 | udachny
# Processing Record 11 of Set 3 | minas de matahambre
# City not found. Skipping...
# Processing Record 12 of Set 3 | zouerate
# Processing Record 13 of Set 3 | manatutu
# City not found. Skipping...
# Processing Record 14 of Set 3 | mozarlandia
# Processing Record 15 of Set 3 | tazovsky
# Processing Record 16 of Set 3 | san carlos de bariloche
# Processing Record 17 of Set 3 | hani
# Processing Record 18 of Set 3 | punta arenas
# Processing Record 19 of Set 3 | papatowai
# Processing Record 20 of Set 3 | port elizabeth
# Processing Record 21 of Set 3 | cacu
# Processing Record 22 of Set 3 | weno
# Processing Record 23 of Set 3 | longyearbyen
# Processing Record 24 of Set 3 | antsohihy
# Processing Record 25 of Set 3 | felipe carrillo puerto
# Processing Record 26 of Set 3 | chibougamau
# Processing Record 27 of Set 3 | nagqu
# Processing Record 28 of Set 3 | mora
# Processing Record 29 of Set 3 | kismayo
# Processing Record 30 of Set 3 | sinan
# Processing Record 31 of Set 3 | tikrit
# Processing Record 32 of Set 3 | callao
# Processing Record 33 of Set 3 | el granada
# Processing Record 34 of Set 3 | talnakh
# Processing Record 35 of Set 3 | city of balikpapan
# Processing Record 36 of Set 3 | xingtai
# Processing Record 37 of Set 3 | tranovaho
# City not found. Skipping...
# Processing Record 38 of Set 3 | lebu
# Processing Record 39 of Set 3 | naze
# Processing Record 40 of Set 3 | vilyuchinsk
# Processing Record 41 of Set 3 | lihue
# Processing Record 42 of Set 3 | metlili chaamba
# Processing Record 43 of Set 3 | manokwari
# Processing Record 44 of Set 3 | ouellah
# City not found. Skipping...
# Processing Record 45 of Set 3 | badger
# Processing Record 46 of Set 3 | keflavik
# Processing Record 47 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 48 of Set 3 | cabedelo
# Processing Record 49 of Set 3 | fraserburgh
# Processing Record 0 of Set 4 | ishigaki
# Processing Record 1 of Set 4 | manicore
# Processing Record 2 of Set 4 | l'alcora
# Processing Record 3 of Set 4 | kronach
# Processing Record 4 of Set 4 | chonchi
# Processing Record 5 of Set 4 | general acha
# Processing Record 6 of Set 4 | feicheng
# Processing Record 7 of Set 4 | inverell
# Processing Record 8 of Set 4 | mil'kovo
# Processing Record 9 of Set 4 | madang
# Processing Record 10 of Set 4 | oranjemund
# Processing Record 11 of Set 4 | kharabali
# Processing Record 12 of Set 4 | porto novo
# Processing Record 13 of Set 4 | atafu village
# Processing Record 14 of Set 4 | namtsy
# Processing Record 15 of Set 4 | mejit
# Processing Record 16 of Set 4 | kupang
# Processing Record 17 of Set 4 | khovd
# Processing Record 18 of Set 4 | bratsk
# Processing Record 19 of Set 4 | tougue
# Processing Record 20 of Set 4 | bozeman
# Processing Record 21 of Set 4 | praia
# Processing Record 22 of Set 4 | hithadhoo
# Processing Record 23 of Set 4 | revelstoke
# Processing Record 24 of Set 4 | tura
# Processing Record 25 of Set 4 | la passe
# Processing Record 26 of Set 4 | safotu
# Processing Record 27 of Set 4 | enewetak
# Processing Record 28 of Set 4 | cacoal
# Processing Record 29 of Set 4 | huarmey
# Processing Record 30 of Set 4 | mossel bay
# Processing Record 31 of Set 4 | aasiaat
# Processing Record 32 of Set 4 | anibare
# City not found. Skipping...
# Processing Record 33 of Set 4 | vorgashor
# Processing Record 34 of Set 4 | santana
# Processing Record 35 of Set 4 | sangin
# Processing Record 36 of Set 4 | tindouf
# Processing Record 37 of Set 4 | alice springs
# Processing Record 38 of Set 4 | carnarvon
# Processing Record 39 of Set 4 | puerto santa
# Processing Record 40 of Set 4 | mikun'
# Processing Record 41 of Set 4 | visby
# Processing Record 42 of Set 4 | ribeira brava
# Processing Record 43 of Set 4 | college
# Processing Record 44 of Set 4 | kennett
# Processing Record 45 of Set 4 | praia da vitoria
# Processing Record 46 of Set 4 | maun
# Processing Record 47 of Set 4 | rongelap
# Processing Record 48 of Set 4 | ancud
# Processing Record 49 of Set 4 | kyshtovka
# Processing Record 0 of Set 5 | yangor
# City not found. Skipping...
# Processing Record 1 of Set 5 | beroroha
# Processing Record 2 of Set 5 | abu jibeha
# Processing Record 3 of Set 5 | guasdualito
# Processing Record 4 of Set 5 | jamestown
# Processing Record 5 of Set 5 | tena
# Processing Record 6 of Set 5 | vadso
# Processing Record 7 of Set 5 | bowling green
# Processing Record 8 of Set 5 | tralee
# Processing Record 9 of Set 5 | jeremoabo
# Processing Record 10 of Set 5 | yaren
# Processing Record 11 of Set 5 | koneurgench
# City not found. Skipping...
# Processing Record 12 of Set 5 | luebo
# Processing Record 13 of Set 5 | susuman
# Processing Record 14 of Set 5 | emerald
# Processing Record 15 of Set 5 | matozinhos
# Processing Record 16 of Set 5 | veinticinco de mayo
# Processing Record 17 of Set 5 | ustyuzhna
# Processing Record 18 of Set 5 | devils lake
# Processing Record 19 of Set 5 | calabozo
# Processing Record 20 of Set 5 | kabwe
# Processing Record 21 of Set 5 | george town
# Processing Record 22 of Set 5 | queenstown
# Processing Record 23 of Set 5 | sitka
# Processing Record 24 of Set 5 | magadan
# Processing Record 25 of Set 5 | hami
# Processing Record 26 of Set 5 | cabo san lucas
# Processing Record 27 of Set 5 | brookings
# Processing Record 28 of Set 5 | sidi ifni
# Processing Record 29 of Set 5 | kingston
# Processing Record 30 of Set 5 | phek
# Processing Record 31 of Set 5 | thurso
# Processing Record 32 of Set 5 | geraldton
# Processing Record 33 of Set 5 | haradok
# Processing Record 34 of Set 5 | papao
# Processing Record 35 of Set 5 | vingt cinq
# City not found. Skipping...
# Processing Record 36 of Set 5 | jalingo
# Processing Record 37 of Set 5 | pasni
# Processing Record 38 of Set 5 | port saint john's
# Processing Record 39 of Set 5 | tondano
# Processing Record 40 of Set 5 | noumea
# Processing Record 41 of Set 5 | devinuwara
# City not found. Skipping...
# Processing Record 42 of Set 5 | pitimbu
# Processing Record 43 of Set 5 | st. john's
# Processing Record 44 of Set 5 | lucapa
# Processing Record 45 of Set 5 | priargunsk
# Processing Record 46 of Set 5 | vilyuysk
# Processing Record 47 of Set 5 | wenling
# Processing Record 48 of Set 5 | la'ie
# Processing Record 49 of Set 5 | labytnangi
# Processing Record 0 of Set 6 | xilin hot
# Processing Record 1 of Set 6 | pita
# Processing Record 2 of Set 6 | sur
# Processing Record 3 of Set 6 | chimoio
# Processing Record 4 of Set 6 | georgetown
# Processing Record 5 of Set 6 | bargara
# City not found. Skipping...
# Processing Record 6 of Set 6 | beberibe
# Processing Record 7 of Set 6 | opuwo
# Processing Record 8 of Set 6 | totolapan
# Processing Record 9 of Set 6 | gamboma
# Processing Record 10 of Set 6 | brisas barra de suchiate
# Processing Record 11 of Set 6 | jackson
# Processing Record 12 of Set 6 | bozhou
# Processing Record 13 of Set 6 | ketchikan
# Processing Record 14 of Set 6 | tabou
# Processing Record 15 of Set 6 | zinjibar
# Processing Record 16 of Set 6 | san jose de feliciano
# Processing Record 17 of Set 6 | helena valley southeast
# Processing Record 18 of Set 6 | corner brook
# Processing Record 19 of Set 6 | luderitz
# Processing Record 20 of Set 6 | laojunmiao
# Processing Record 21 of Set 6 | dzuunmod
# Processing Record 22 of Set 6 | mariental
# Processing Record 23 of Set 6 | hadibu
# Processing Record 24 of Set 6 | ahau
# City not found. Skipping...
# Processing Record 25 of Set 6 | mogok
# Processing Record 26 of Set 6 | tamanrasset
# Processing Record 27 of Set 6 | christchurch
# Processing Record 28 of Set 6 | felidhoo
# City not found. Skipping...
# Processing Record 29 of Set 6 | constitucion
# Processing Record 30 of Set 6 | castillos
# Processing Record 31 of Set 6 | mahina
# Processing Record 32 of Set 6 | sydney
# Processing Record 33 of Set 6 | malanje
# Processing Record 34 of Set 6 | olyokminsk
# Processing Record 35 of Set 6 | crane
# Processing Record 36 of Set 6 | ozersk
# Processing Record 37 of Set 6 | katsuura
# Processing Record 38 of Set 6 | lompoc
# Processing Record 39 of Set 6 | la ronge
# Processing Record 40 of Set 6 | vernon
# Processing Record 41 of Set 6 | naha
# Processing Record 42 of Set 6 | rossleben
# Processing Record 43 of Set 6 | namibe
# Processing Record 44 of Set 6 | isangel
# Processing Record 45 of Set 6 | yelizovo
# Processing Record 46 of Set 6 | saguenay
# Processing Record 47 of Set 6 | sattahip
# Processing Record 48 of Set 6 | mananjary
# Processing Record 49 of Set 6 | vail
# Processing Record 0 of Set 7 | saudarkrokur
# Processing Record 1 of Set 7 | kourou
# Processing Record 2 of Set 7 | mount gambier
# Processing Record 3 of Set 7 | okha
# Processing Record 4 of Set 7 | dauphin
# Processing Record 5 of Set 7 | jakobstad
# Processing Record 6 of Set 7 | blenheim
# Processing Record 7 of Set 7 | cordoba
# Processing Record 8 of Set 7 | lazaro cardenas
# Processing Record 9 of Set 7 | port lincoln
# Processing Record 10 of Set 7 | jinghong
# Processing Record 11 of Set 7 | lulea
# Processing Record 12 of Set 7 | paracuru
# Processing Record 13 of Set 7 | soloma
# Processing Record 14 of Set 7 | lienz
# Processing Record 15 of Set 7 | las veredas
# Processing Record 16 of Set 7 | chipinge
# Processing Record 17 of Set 7 | altai
# Processing Record 18 of Set 7 | slavyanka
# Processing Record 19 of Set 7 | arroio dos ratos
# Processing Record 20 of Set 7 | tofol
# Processing Record 21 of Set 7 | awjilah
# Processing Record 22 of Set 7 | yatou
# Processing Record 23 of Set 7 | tolanaro
# Processing Record 24 of Set 7 | nadym
# Processing Record 25 of Set 7 | baloda
# Processing Record 26 of Set 7 | nyurba
# Processing Record 27 of Set 7 | quellon
# Processing Record 28 of Set 7 | saldanha
# Processing Record 29 of Set 7 | fort bragg
# Processing Record 30 of Set 7 | bel ombre
# Processing Record 31 of Set 7 | itoman
# Processing Record 32 of Set 7 | torrington
# Processing Record 33 of Set 7 | bokoro
# Processing Record 34 of Set 7 | timbuktu
# Processing Record 35 of Set 7 | puerto carreno
# Processing Record 36 of Set 7 | sagua la grande
# Processing Record 37 of Set 7 | sadovoye
# Processing Record 38 of Set 7 | piti village
# Processing Record 39 of Set 7 | island harbour
# Processing Record 40 of Set 7 | mason city
# Processing Record 41 of Set 7 | songea
# Processing Record 42 of Set 7 | akhmim
# Processing Record 43 of Set 7 | dazhou
# Processing Record 44 of Set 7 | granite shoals
# Processing Record 45 of Set 7 | miandrivazo
# Processing Record 46 of Set 7 | dubbo
# Processing Record 47 of Set 7 | tanabe
# Processing Record 48 of Set 7 | padang
# Processing Record 49 of Set 7 | helong
# Processing Record 0 of Set 8 | novoshakhtinskiy
# Processing Record 1 of Set 8 | gondia
# Processing Record 2 of Set 8 | kalmunai
# Processing Record 3 of Set 8 | changling
# Processing Record 4 of Set 8 | nongstoin
# Processing Record 5 of Set 8 | al kharijah
# Processing Record 6 of Set 8 | purpe
# Processing Record 7 of Set 8 | port-vila
# Processing Record 8 of Set 8 | dunedin
# Processing Record 9 of Set 8 | gurupi
# Processing Record 10 of Set 8 | fort st. john
# Processing Record 11 of Set 8 | thinadhoo
# Processing Record 12 of Set 8 | yuzhno-kurilsk
# Processing Record 13 of Set 8 | haiku-pauwela
# Processing Record 14 of Set 8 | minas de marcona
# Processing Record 15 of Set 8 | el hadjira
# Processing Record 16 of Set 8 | cairns city
# City not found. Skipping...
# Processing Record 17 of Set 8 | abu dhabi
# Processing Record 18 of Set 8 | prado
# Processing Record 19 of Set 8 | bocas del toro
# Processing Record 20 of Set 8 | dededo village
# Processing Record 21 of Set 8 | pontes e lacerda
# Processing Record 22 of Set 8 | okhotsk
# Processing Record 23 of Set 8 | kodiak
# Processing Record 24 of Set 8 | santyoku
# Processing Record 25 of Set 8 | aspe
# Processing Record 26 of Set 8 | lobujya
# Processing Record 27 of Set 8 | kiunga
# Processing Record 28 of Set 8 | samfya
# Processing Record 29 of Set 8 | nantucket
# Processing Record 30 of Set 8 | arraial do cabo
# Processing Record 31 of Set 8 | parepare
# City not found. Skipping...
# Processing Record 32 of Set 8 | pachino
# Processing Record 33 of Set 8 | rikaze
# Processing Record 34 of Set 8 | sao felix do xingu
# Processing Record 35 of Set 8 | colonia
# Processing Record 36 of Set 8 | palmer
# Processing Record 37 of Set 8 | hotan
# Processing Record 38 of Set 8 | usinsk
# Processing Record 39 of Set 8 | ubinskoye
# Processing Record 40 of Set 8 | puerto baquerizo moreno
# Processing Record 41 of Set 8 | hoxtolgay
# City not found. Skipping...
# Processing Record 42 of Set 8 | aoulef
# Processing Record 43 of Set 8 | zhanaozen
# Processing Record 44 of Set 8 | oltinko'l
# Processing Record 45 of Set 8 | dudinka
# Processing Record 46 of Set 8 | sisimiut
# Processing Record 47 of Set 8 | iskateley
# Processing Record 48 of Set 8 | angaur state
# Processing Record 49 of Set 8 | codrington
# Processing Record 0 of Set 9 | hasaki
# Processing Record 1 of Set 9 | uaua
# Processing Record 2 of Set 9 | tshabong
# Processing Record 3 of Set 9 | xiannu
# Processing Record 4 of Set 9 | puerto aysen
# Processing Record 5 of Set 9 | sungai penuh
# Processing Record 6 of Set 9 | motygino
# Processing Record 7 of Set 9 | west bay
# Processing Record 8 of Set 9 | klaksvik
# Processing Record 9 of Set 9 | vila velha
# Processing Record 10 of Set 9 | cargados carajos
# City not found. Skipping...
# Processing Record 11 of Set 9 | kruhlaye
# Processing Record 12 of Set 9 | itaituba
# Processing Record 13 of Set 9 | arauco
# Processing Record 14 of Set 9 | cartagena
# Processing Record 15 of Set 9 | vryheid
# Processing Record 16 of Set 9 | marquette
# Processing Record 17 of Set 9 | hexham
# Processing Record 18 of Set 9 | turpan
# Processing Record 19 of Set 9 | inhambane
# Processing Record 20 of Set 9 | bayan nur
# City not found. Skipping...
# Processing Record 21 of Set 9 | myitkyina
# Processing Record 22 of Set 9 | bo
# City not found. Skipping...
# Processing Record 23 of Set 9 | moyynkum
# Processing Record 24 of Set 9 | attapeu
# Processing Record 25 of Set 9 | the bottom
# Processing Record 26 of Set 9 | greymouth
# Processing Record 27 of Set 9 | mount isa
# Processing Record 28 of Set 9 | mount pearl
# Processing Record 29 of Set 9 | hungund
# Processing Record 30 of Set 9 | taroa
# Processing Record 31 of Set 9 | ain beni mathar
# City not found. Skipping...
# Processing Record 32 of Set 9 | bubaque
# Processing Record 33 of Set 9 | firuzabad
# Processing Record 34 of Set 9 | batie
# Processing Record 35 of Set 9 | toktogul
# Processing Record 36 of Set 9 | chandler
# Processing Record 37 of Set 9 | mae sot
# Processing Record 38 of Set 9 | kununurra
# Processing Record 39 of Set 9 | markaz-e hukumat-e darweshan
# Processing Record 40 of Set 9 | ola
# Processing Record 41 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 42 of Set 9 | badeggi
# Processing Record 43 of Set 9 | afif
# Processing Record 44 of Set 9 | palopo
# Processing Record 45 of Set 9 | paka
# Processing Record 46 of Set 9 | jinchang
# Processing Record 47 of Set 9 | amga
# Processing Record 48 of Set 9 | manakara
# Processing Record 49 of Set 9 | taksimo
# Processing Record 0 of Set 10 | menongue
# Processing Record 1 of Set 10 | sherbakul'
# Processing Record 2 of Set 10 | ghazni
# Processing Record 3 of Set 10 | westport
# Processing Record 4 of Set 10 | tromso
# Processing Record 5 of Set 10 | vieste
# Processing Record 6 of Set 10 | lembar
# City not found. Skipping...
# Processing Record 7 of Set 10 | glace bay
# Processing Record 8 of Set 10 | korsakov
# Processing Record 9 of Set 10 | thunder bay
# Processing Record 10 of Set 10 | egilsstadir
# Processing Record 11 of Set 10 | uliastay
# Processing Record 12 of Set 10 | granja
# Processing Record 13 of Set 10 | tete
# Processing Record 14 of Set 10 | posse
# Processing Record 15 of Set 10 | prymors'k
# Processing Record 16 of Set 10 | ulaangom
# Processing Record 17 of Set 10 | tambacounda
# Processing Record 18 of Set 10 | runka
# Processing Record 19 of Set 10 | kalaleh
# Processing Record 20 of Set 10 | orange walk
# Processing Record 21 of Set 10 | howrah
# Processing Record 22 of Set 10 | tateyama
# Processing Record 23 of Set 10 | ciudad bolivar
# Processing Record 24 of Set 10 | polyarnyy
# Processing Record 25 of Set 10 | kristiansund
# Processing Record 26 of Set 10 | thetford
# Processing Record 27 of Set 10 | lichtenburg
# Processing Record 28 of Set 10 | saeby
# Processing Record 29 of Set 10 | puerto deseado
# Processing Record 30 of Set 10 | severobaykal'sk
# Processing Record 31 of Set 10 | marienthal
# Processing Record 32 of Set 10 | kilindoni
# Processing Record 33 of Set 10 | rye
# Processing Record 34 of Set 10 | shingu
# Processing Record 35 of Set 10 | ujae
# Processing Record 36 of Set 10 | tarinkot
# Processing Record 37 of Set 10 | morehead city
# Processing Record 38 of Set 10 | al mithnab
# City not found. Skipping...
# Processing Record 39 of Set 10 | tokonou
# Processing Record 40 of Set 10 | el porvenir
# Processing Record 41 of Set 10 | pangody
# Processing Record 42 of Set 10 | olovyannaya
# Processing Record 43 of Set 10 | khandyga
# Processing Record 44 of Set 10 | bao loc
# City not found. Skipping...
# Processing Record 45 of Set 10 | alofi
# Processing Record 46 of Set 10 | shixing
# Processing Record 47 of Set 10 | gangi
# Processing Record 48 of Set 10 | bardai
# Processing Record 49 of Set 10 | takamaka
# City not found. Skipping...
# Processing Record 0 of Set 11 | alpena
# Processing Record 1 of Set 11 | monrovia
# Processing Record 2 of Set 11 | ko pha ngan
# Processing Record 3 of Set 11 | oume
# Processing Record 4 of Set 11 | bikenibeu village
# Processing Record 5 of Set 11 | harstad
# Processing Record 6 of Set 11 | rosiorii de vede
# Processing Record 7 of Set 11 | sheregesh
# Processing Record 8 of Set 11 | pemba
# Processing Record 9 of Set 11 | kirensk
# Processing Record 10 of Set 11 | sorong
# Processing Record 11 of Set 11 | poltavka
# Processing Record 12 of Set 11 | darwin
# Processing Record 13 of Set 11 | qala i naw
# Processing Record 14 of Set 11 | taro
# Processing Record 15 of Set 11 | malango
# Processing Record 16 of Set 11 | zambezi
# Processing Record 17 of Set 11 | kataragama
# City not found. Skipping...
# Processing Record 18 of Set 11 | yemetsk
# Processing Record 19 of Set 11 | urangan
# Processing Record 20 of Set 11 | corn island
# Processing Record 21 of Set 11 | broome
# Processing Record 22 of Set 11 | fuvahmulah
# City not found. Skipping...
# Processing Record 23 of Set 11 | phayakkhaphum phisai
# Processing Record 24 of Set 11 | walvis bay
# Processing Record 25 of Set 11 | buwenge
# Processing Record 26 of Set 11 | blagoveshchensk
# Processing Record 27 of Set 11 | saint-philippe
# Processing Record 28 of Set 11 | wewak
# Processing Record 29 of Set 11 | northam
# Processing Record 30 of Set 11 | kayangel
# Processing Record 31 of Set 11 | al ghayzah
# Processing Record 32 of Set 11 | antakya
# Processing Record 33 of Set 11 | kualakapuas
# Processing Record 34 of Set 11 | miguel ahumada
# Processing Record 35 of Set 11 | keita
# Processing Record 36 of Set 11 | oodweyne
# Processing Record 37 of Set 11 | broken hill
# Processing Record 38 of Set 11 | tahe
# Processing Record 39 of Set 11 | sonsorol village
# City not found. Skipping...
# Processing Record 40 of Set 11 | kapuskasing
# Processing Record 41 of Set 11 | virginia
# Processing Record 42 of Set 11 | palangkaraya
# Processing Record 43 of Set 11 | kaka
# Processing Record 44 of Set 11 | evanston
# Processing Record 45 of Set 11 | rio tuba
# Processing Record 46 of Set 11 | sandnessjoen
# Processing Record 47 of Set 11 | scottburgh
# Processing Record 48 of Set 11 | paramirim
# Processing Record 49 of Set 11 | fisterra
# Processing Record 0 of Set 12 | plastun
# Processing Record 1 of Set 12 | kargasok
# Processing Record 2 of Set 12 | gadzhiyevo
# Processing Record 3 of Set 12 | cockburn town
# Processing Record 4 of Set 12 | selfoss
# Processing Record 5 of Set 12 | salalah
# Processing Record 6 of Set 12 | richards bay
# Processing Record 7 of Set 12 | east ballina
# Processing Record 8 of Set 12 | acarau
# Processing Record 9 of Set 12 | bonthe
# Processing Record 10 of Set 12 | smara
# Processing Record 11 of Set 12 | elek
# Processing Record 12 of Set 12 | nemuro
# Processing Record 13 of Set 12 | cidade velha
# Processing Record 14 of Set 12 | nzega
# Processing Record 15 of Set 12 | lawton
# Processing Record 16 of Set 12 | rajpipla
# Processing Record 17 of Set 12 | porto murtinho
# Processing Record 18 of Set 12 | jayapura
# Processing Record 19 of Set 12 | machali
# Processing Record 20 of Set 12 | grootfontein
# Processing Record 21 of Set 12 | paris
# Processing Record 22 of Set 12 | jabat
# Processing Record 23 of Set 12 | whitby
# Processing Record 24 of Set 12 | alexandria
# Processing Record 25 of Set 12 | toliara
# Processing Record 26 of Set 12 | ceerigaabo
# Processing Record 27 of Set 12 | champerico
# Processing Record 28 of Set 12 | puerto san carlos
# City not found. Skipping...
# Processing Record 29 of Set 12 | howard springs
# Processing Record 30 of Set 12 | lae
# Processing Record 31 of Set 12 | sarakhs
# Processing Record 32 of Set 12 | mar del plata
# Processing Record 33 of Set 12 | alesund
# Processing Record 34 of Set 12 | shenjiamen
# Processing Record 35 of Set 12 | belem
# Processing Record 36 of Set 12 | akureyri
# Processing Record 37 of Set 12 | cumana
# Processing Record 38 of Set 12 | ixtapa
# Processing Record 39 of Set 12 | saint-francois
# Processing Record 40 of Set 12 | yendi
# Processing Record 41 of Set 12 | robore
# Processing Record 42 of Set 12 | maragogi
# Processing Record 43 of Set 12 | hilo
# Processing Record 44 of Set 12 | rumoi
# Processing Record 45 of Set 12 | suwayr
# Processing Record 46 of Set 12 | cururupu
# Processing Record 47 of Set 12 | illizi
# Processing Record 48 of Set 12 | buka
# Processing Record 49 of Set 12 | argo
# Processing Record 0 of Set 13 | hailey
# Processing Record 1 of Set 13 | vorkuta
# Processing Record 2 of Set 13 | road town
# Processing Record 3 of Set 13 | ananindeua
# Processing Record 4 of Set 13 | wajir
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_weather
# Out:
# {'coord': {'lon': 40.0573, 'lat': 1.7471},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03d'}],
#  'base': 'stations',
#  'main': {'temp': 31.98,
#   'feels_like': 35.6,
#   'temp_min': 31.98,
#   'temp_max': 31.98,
#   'pressure': 1007,
#   'humidity': 55},
#  'visibility': 10000,
#  'wind': {'speed': 3.6, 'deg': 90},
#  'clouds': {'all': 40},
#  'dt': 1699541197,
#  'sys': {'type': 1,
#   'id': 2571,
#   'country': 'KE',
#   'sunrise': 1699498933,
#   'sunset': 1699542297},
#  'timezone': 10800,
#  'id': 178443,
#  'name': 'Wajir',
#  'cod': 200}

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df

# Show Record Count
city_data_df.count()
# Out:
# City          574
# Lat           574
# Lng           574
# Max Temp      574
# Humidity      574
# Cloudiness    574
# Wind Speed    574
# Country       574
# Date          574
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#        City      Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     sinop  41.7711  41.7711     10.82        90         100        2.45
# 1  tangalle   6.0240   6.0240     24.09        94         100        3.41
# 2  thompson  55.7435  55.7435     -7.83        85          95        3.64
# 3     kyren  51.6828  51.6828    -14.47        87           2        0.89
# 4   ushuaia -54.8000 -54.8000     10.81        39           0        6.17
#
#   Country        Date
# 0      TR  1699542434
# 1      LK  1699542434
# 2      CA  1699542435
# 3      RU  1699542435
# 4      AR  1699542436

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#              City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           sinop  41.7711  41.7711     10.82        90         100
# 1        tangalle   6.0240   6.0240     24.09        94         100
# 2        thompson  55.7435  55.7435     -7.83        85          95
# 3           kyren  51.6828  51.6828    -14.47        87           2
# 4         ushuaia -54.8000 -54.8000     10.81        39           0
#
#          Wind Speed Country        Date
# City_ID
# 0              2.45      TR  1699542434
# 1              3.41      LK  1699542434
# 2              3.64      CA  1699542435
# 3              0.89      RU  1699542435
# 4              6.17      AR  1699542436

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_values = city_data_df['Lat']
y_values = city_data_df['Max Temp']
plt.scatter(x_values,y_values,marker="o",facecolors='blue',edgecolors='black',)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.grid(True)

# Incorporate the other graph properties
plt.title('City Latitude vs Max Temperature (2023-11-9)')

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_values = city_data_df['Lat']
y_values = city_data_df['Humidity']
plt.scatter(x_values,y_values,marker="o",facecolors='blue',edgecolors='black',)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)

# Incorporate the other graph properties
plt.title('City Latitude vs Humidity (2023-11-9)')

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_values = city_data_df['Lat']
y_values = city_data_df['Cloudiness']
plt.scatter(x_values,y_values,marker="o",facecolors='blue',edgecolors='black',)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)

# Incorporate the other graph properties
plt.title('City Latitude vs Cloudiness (2023-11-9)')

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_values = city_data_df['Lat']
y_values = city_data_df['Wind Speed']
plt.scatter(x_values,y_values,marker="o",facecolors='blue',edgecolors='black',)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.grid(True)


# Incorporate the other graph properties
plt.title('City Latitude vs Wind Speed (2023-11-9)')

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linearRegression(x_values,y_values, regEQplotX, regEQplotY, ylabel):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values, marker="o", facecolors="blue")
    plt.plot(x_values,regress_values,"r-", linewidth=3)
    plt.grid(True)
    print(f'The r-value is {rvalue}')
    plt.annotate(line_eq,(regEQplotX,regEQplotY),color="red")
    plt.xlabel('Latitude')
    plt.ylabel(f'{ylabel}')
    plt.grid()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)city_data_df
northern_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]).astype(float)>= 0, :]
northern_hemi_df
# Display sample data
northern_hemi_df.head()
# Out:
#              City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           sinop  41.7711  41.7711     10.82        90         100
# 1        tangalle   6.0240   6.0240     24.09        94         100
# 2        thompson  55.7435  55.7435     -7.83        85          95
# 3           kyren  51.6828  51.6828    -14.47        87           2
# 5         iqaluit  63.7506  63.7506     -1.28        68         100
#
#          Wind Speed Country        Date
# City_ID
# 0              2.45      TR  1699542434
# 1              3.41      LK  1699542434
# 2              3.64      CA  1699542435
# 3              0.89      RU  1699542435
# 5              6.71      CA  1699542436

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]).astype(float)< 0, :]
southern_hemi_df

# Display sample data
southern_hemi_df.head()
# Out:
#                         City      Lat      Lng  Max Temp  Humidity  \
# City_ID
# 4                    ushuaia -54.8000 -54.8000     10.81        39
# 6             puerto natales -51.7236 -51.7236     13.25        35
# 9               invercargill -46.4000 -46.4000      2.79        91
# 10       fale old settlement  -9.3852  -9.3852     28.43        73
# 11                    avarua -21.2078 -21.2078     23.03        83
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 4                 0        6.17      AR  1699542436
# 6                40       11.32      CL  1699542437
# 9                 3        1.65      NZ  1699542339
# 10              100        2.02      TK  1699542438
# 11               40        5.14      CK  1699542439

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_plot = northern_hemi_df["Lat"]
y_plot = northern_hemi_df["Max Temp"]
linearRegression(x_plot, y_plot, 5, -20, "Temperature (C)")
plt.savefig("output_data/Fig5.png",dpi=300, bbox_inches = "tight")
# Out:
# The r-value is -0.8516794990338948

# %%
# Linear regression on Southern Hemisphere
x_plot = southern_hemi_df["Lat"]
y_plot = southern_hemi_df["Max Temp"]
linearRegression(x_plot, y_plot, -55, 35, "Temperature (C)")
plt.savefig("output_data/Fig6.png",dpi=300, bbox_inches = "tight")
# Out:
# The r-value is 0.7073525998526049

# %% [markdown]
# Discussion about the linear relationship:
# Latitude vs Temperature - As expected, the farther away from the equator we travel, the max temperature is lower.  Both r-values are high enough to show that there is a correlation.  The r-value correlation is slightly higher in the northern hemisphere.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_plot = northern_hemi_df["Lat"]
y_plot = northern_hemi_df["Humidity"]
linearRegression(x_plot, y_plot, 50, 20, "Humidity (%)")
plt.savefig("output_data/Fig7.png",dpi=300, bbox_inches = "tight")
# Out:
# The r-value is 0.4023598780970621

# %%
# Southern Hemisphere
x_plot = southern_hemi_df["Lat"]
y_plot = southern_hemi_df["Humidity"]
linearRegression(x_plot, y_plot, -15, 10, "Humidity (%)")
plt.savefig("output_data/Fig8.png",dpi=300, bbox_inches = "tight")
# Out:
# The r-value is 0.0722579270875529

# %% [markdown]
# Discussion about the linear relationship:
# According to the data, there is no correlation of the level of humidity compared to the distance from the equator.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_plot = northern_hemi_df["Lat"]
y_plot = northern_hemi_df["Cloudiness"]
linearRegression(x_plot, y_plot, 50, 10, "Cloudiness (%)")
plt.savefig("output_data/Fig7.png",dpi=300, bbox_inches = "tight")
# Out:
# The r-value is 0.1891706580220569

# %%
# Southern Hemisphere
x_plot = southern_hemi_df["Lat"]
y_plot = southern_hemi_df["Cloudiness"]
linearRegression(x_plot, y_plot, -50, 50, "Cloudiness (%)")
plt.savefig("output_data/Fig7.png",dpi=300, bbox_inches = "tight")
# Out:
# The r-value is 0.30427731034006805

# %% [markdown]
# Discussion about the linear relationship:
# There is a slightly higher correlation in the southern atmosphere.  But there is still no significant correlation between cloudiness and distance from the equator.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_plot = northern_hemi_df["Lat"]
y_plot = northern_hemi_df["Wind Speed"]
linearRegression(x_plot, y_plot, 50, 15, "Wind Speed (m/s)")
plt.savefig("output_data/Fig7.png",dpi=300, bbox_inches = "tight")
# Out:
# The r-value is 0.09841547983873855

# %%
# Southern Hemisphere
x_plot = southern_hemi_df["Lat"]
y_plot = southern_hemi_df["Wind Speed"]
linearRegression(x_plot, y_plot, -50, 10, "Wind Speed (m/s)")
plt.savefig("output_data/Fig7.png",dpi=300, bbox_inches = "tight")
# Out:
# The r-value is -0.14654613236361108

# %% [markdown]
# Discussion about the linear relationship:
# According to the data, there is no correlation of the level of humidity compared to the distance from the equator.
