# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 614

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "appid=" + weather_api_key + "&q=" + city + "&units=metric"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | remire-montjoly
# Processing Record 2 of Set 1 | yellowknife
# Processing Record 3 of Set 1 | longyearbyen
# Processing Record 4 of Set 1 | midvagur
# Processing Record 5 of Set 1 | nieuw amsterdam
# Processing Record 6 of Set 1 | port-aux-francais
# Processing Record 7 of Set 1 | blackmans bay
# Processing Record 8 of Set 1 | margaret river
# Processing Record 9 of Set 1 | sao joao da barra
# Processing Record 10 of Set 1 | stanley
# Processing Record 11 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 12 of Set 1 | uturoa
# Processing Record 13 of Set 1 | ust-nera
# Processing Record 14 of Set 1 | edinburgh of the seven seas
# Processing Record 15 of Set 1 | qaqortoq
# Processing Record 16 of Set 1 | grytviken
# Processing Record 17 of Set 1 | waitangi
# Processing Record 18 of Set 1 | udachny
# Processing Record 19 of Set 1 | bethel
# Processing Record 20 of Set 1 | constitucion
# Processing Record 21 of Set 1 | puerto natales
# Processing Record 22 of Set 1 | georgetown
# Processing Record 23 of Set 1 | port shepstone
# Processing Record 24 of Set 1 | cole harbour
# Processing Record 25 of Set 1 | papatowai
# Processing Record 26 of Set 1 | lospalos
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | sisimiut
# Processing Record 29 of Set 1 | phu khiao
# Processing Record 30 of Set 1 | port-saint-louis-du-rhone
# Processing Record 31 of Set 1 | ares
# Processing Record 32 of Set 1 | viana do castelo
# Processing Record 33 of Set 1 | bardai
# Processing Record 34 of Set 1 | ilulissat
# Processing Record 35 of Set 1 | isafjordur
# Processing Record 36 of Set 1 | lamu
# Processing Record 37 of Set 1 | arkhangel'sk
# Processing Record 38 of Set 1 | tobelo
# Processing Record 39 of Set 1 | ciudad lazaro cardenas
# Processing Record 40 of Set 1 | st. john's
# Processing Record 41 of Set 1 | port douglas
# Processing Record 42 of Set 1 | adamstown
# Processing Record 43 of Set 1 | port mathurin
# Processing Record 44 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 45 of Set 1 | mount gambier
# Processing Record 46 of Set 1 | alice springs
# Processing Record 47 of Set 1 | wynyard
# Processing Record 48 of Set 1 | ushuaia
# Processing Record 49 of Set 1 | lazaro cardenas
# Processing Record 50 of Set 1 | puerto ayora
# Processing Record 0 of Set 2 | dudinka
# Processing Record 1 of Set 2 | shalya
# Processing Record 2 of Set 2 | kingston
# Processing Record 3 of Set 2 | miri
# Processing Record 4 of Set 2 | tolanaro
# Processing Record 5 of Set 2 | margate
# Processing Record 6 of Set 2 | iqaluit
# Processing Record 7 of Set 2 | puerto san carlos
# City not found. Skipping...
# Processing Record 8 of Set 2 | mana
# Processing Record 9 of Set 2 | jagna
# Processing Record 10 of Set 2 | hamilton
# Processing Record 11 of Set 2 | mburucuya
# Processing Record 12 of Set 2 | saint-pierre
# Processing Record 13 of Set 2 | iskateley
# Processing Record 14 of Set 2 | jamestown
# Processing Record 15 of Set 2 | happy valley-goose bay
# Processing Record 16 of Set 2 | ancud
# Processing Record 17 of Set 2 | kavieng
# Processing Record 18 of Set 2 | sinop
# Processing Record 19 of Set 2 | livadeia
# Processing Record 20 of Set 2 | whakatane
# Processing Record 21 of Set 2 | bandarbeyla
# Processing Record 22 of Set 2 | enewetak
# Processing Record 23 of Set 2 | dawei
# Processing Record 24 of Set 2 | albertina
# Processing Record 25 of Set 2 | orichi
# Processing Record 26 of Set 2 | gereida
# Processing Record 27 of Set 2 | laguna
# Processing Record 28 of Set 2 | yarkovo
# Processing Record 29 of Set 2 | la ronge
# Processing Record 30 of Set 2 | alta
# Processing Record 31 of Set 2 | ribeira grande
# Processing Record 32 of Set 2 | weno
# Processing Record 33 of Set 2 | sake
# Processing Record 34 of Set 2 | talnakh
# Processing Record 35 of Set 2 | uglegorsk
# Processing Record 36 of Set 2 | lebu
# Processing Record 37 of Set 2 | yokohama
# Processing Record 38 of Set 2 | shingu
# Processing Record 39 of Set 2 | constantia
# Processing Record 40 of Set 2 | touros
# Processing Record 41 of Set 2 | keflavik
# Processing Record 42 of Set 2 | nagqu
# Processing Record 43 of Set 2 | boguchany
# Processing Record 44 of Set 2 | east london
# Processing Record 45 of Set 2 | port elizabeth
# Processing Record 46 of Set 2 | tazovsky
# Processing Record 47 of Set 2 | lerwick
# Processing Record 48 of Set 2 | avarua
# Processing Record 49 of Set 2 | port alfred
# Processing Record 0 of Set 3 | klyuchi
# Processing Record 1 of Set 3 | bam
# Processing Record 2 of Set 3 | mugia
# Processing Record 3 of Set 3 | west island
# Processing Record 4 of Set 3 | anadyr
# Processing Record 5 of Set 3 | butte
# Processing Record 6 of Set 3 | saipan
# Processing Record 7 of Set 3 | port augusta
# Processing Record 8 of Set 3 | minas de marcona
# Processing Record 9 of Set 3 | santa maria do para
# Processing Record 10 of Set 3 | isangel
# Processing Record 11 of Set 3 | tiksi
# Processing Record 12 of Set 3 | island harbour
# Processing Record 13 of Set 3 | atafu village
# Processing Record 14 of Set 3 | hermanus
# Processing Record 15 of Set 3 | invercargill
# Processing Record 16 of Set 3 | undurkhaan
# Processing Record 17 of Set 3 | puerto aysen
# Processing Record 18 of Set 3 | alofi
# Processing Record 19 of Set 3 | vilyuchinsk
# Processing Record 20 of Set 3 | makubetsu
# Processing Record 21 of Set 3 | bubaque
# Processing Record 22 of Set 3 | beruwala
# Processing Record 23 of Set 3 | karatuzskoye
# Processing Record 24 of Set 3 | kelaat mgouna
# City not found. Skipping...
# Processing Record 25 of Set 3 | luderitz
# Processing Record 26 of Set 3 | mahina
# Processing Record 27 of Set 3 | badger
# Processing Record 28 of Set 3 | polyarnyy
# Processing Record 29 of Set 3 | ivins
# Processing Record 30 of Set 3 | vorgashor
# Processing Record 31 of Set 3 | arraial do cabo
# Processing Record 32 of Set 3 | bredasdorp
# Processing Record 33 of Set 3 | taroa
# Processing Record 34 of Set 3 | cable beach
# City not found. Skipping...
# Processing Record 35 of Set 3 | fale old settlement
# Processing Record 36 of Set 3 | clemencia
# Processing Record 37 of Set 3 | bonthe
# Processing Record 38 of Set 3 | cabo san lucas
# Processing Record 39 of Set 3 | hasaki
# Processing Record 40 of Set 3 | jimaguayu
# City not found. Skipping...
# Processing Record 41 of Set 3 | tralee
# Processing Record 42 of Set 3 | yuma
# Processing Record 43 of Set 3 | inongo
# Processing Record 44 of Set 3 | simplicio mendes
# Processing Record 45 of Set 3 | porto novo
# Processing Record 46 of Set 3 | gueltat zemmour
# City not found. Skipping...
# Processing Record 47 of Set 3 | santa elena de uairen
# Processing Record 48 of Set 3 | afaahiti
# Processing Record 49 of Set 3 | fougeres
# Processing Record 0 of Set 4 | san rafael
# Processing Record 1 of Set 4 | nabire
# Processing Record 2 of Set 4 | celendin
# Processing Record 3 of Set 4 | gangakher
# Processing Record 4 of Set 4 | dakar
# Processing Record 5 of Set 4 | rio gallegos
# Processing Record 6 of Set 4 | coquimbo
# Processing Record 7 of Set 4 | ambovombe
# Processing Record 8 of Set 4 | tazacorte
# Processing Record 9 of Set 4 | kutum
# Processing Record 10 of Set 4 | kiunga
# Processing Record 11 of Set 4 | 'ohonua
# City not found. Skipping...
# Processing Record 12 of Set 4 | naze
# Processing Record 13 of Set 4 | oistins
# Processing Record 14 of Set 4 | trinidad
# Processing Record 15 of Set 4 | sredniy
# Processing Record 16 of Set 4 | powell river
# Processing Record 17 of Set 4 | sitka
# Processing Record 18 of Set 4 | jabat
# Processing Record 19 of Set 4 | kendari
# Processing Record 20 of Set 4 | bayanhongor
# Processing Record 21 of Set 4 | kodiak
# Processing Record 22 of Set 4 | kismayo
# Processing Record 23 of Set 4 | nuuk
# Processing Record 24 of Set 4 | hawaiian paradise park
# Processing Record 25 of Set 4 | xinshi
# Processing Record 26 of Set 4 | phan rang-thap cham
# Processing Record 27 of Set 4 | albany
# Processing Record 28 of Set 4 | whitehorse
# Processing Record 29 of Set 4 | rovaniemi
# Processing Record 30 of Set 4 | nova sintra
# Processing Record 31 of Set 4 | dryden
# Processing Record 32 of Set 4 | muriti
# Processing Record 33 of Set 4 | turkmenabat
# Processing Record 34 of Set 4 | mao
# Processing Record 35 of Set 4 | gamboma
# Processing Record 36 of Set 4 | egilsstadir
# Processing Record 37 of Set 4 | alo
# Processing Record 38 of Set 4 | el nido
# Processing Record 39 of Set 4 | leava
# Processing Record 40 of Set 4 | vingt cinq
# City not found. Skipping...
# Processing Record 41 of Set 4 | manicore
# Processing Record 42 of Set 4 | nikolayevsk-on-amure
# Processing Record 43 of Set 4 | khandyga
# Processing Record 44 of Set 4 | ta`u
# Processing Record 45 of Set 4 | mukah
# City not found. Skipping...
# Processing Record 46 of Set 4 | tangalle
# Processing Record 47 of Set 4 | monte carmelo
# Processing Record 48 of Set 4 | paita
# Processing Record 49 of Set 4 | kingsland
# Processing Record 0 of Set 5 | selfoss
# Processing Record 1 of Set 5 | las vegas
# Processing Record 2 of Set 5 | susuman
# Processing Record 3 of Set 5 | labrador city
# Processing Record 4 of Set 5 | visby
# Processing Record 5 of Set 5 | wailua homesteads
# Processing Record 6 of Set 5 | mawlaik
# Processing Record 7 of Set 5 | codrington
# Processing Record 8 of Set 5 | sandnessjoen
# Processing Record 9 of Set 5 | bargaal
# Processing Record 10 of Set 5 | tofol
# Processing Record 11 of Set 5 | thinadhoo
# Processing Record 12 of Set 5 | chippewa falls
# Processing Record 13 of Set 5 | labytnangi
# Processing Record 14 of Set 5 | tromso
# Processing Record 15 of Set 5 | port lincoln
# Processing Record 16 of Set 5 | bargara
# City not found. Skipping...
# Processing Record 17 of Set 5 | amga
# Processing Record 18 of Set 5 | kinel'-cherkassy
# Processing Record 19 of Set 5 | aasiaat
# Processing Record 20 of Set 5 | magadan
# Processing Record 21 of Set 5 | palmer
# Processing Record 22 of Set 5 | bilibino
# Processing Record 23 of Set 5 | tadine
# Processing Record 24 of Set 5 | charikar
# Processing Record 25 of Set 5 | fuyu
# Processing Record 26 of Set 5 | safonovo
# Processing Record 27 of Set 5 | santa maria
# Processing Record 28 of Set 5 | flying fish cove
# Processing Record 29 of Set 5 | at taj
# Processing Record 30 of Set 5 | las khorey
# Processing Record 31 of Set 5 | volodarskiy
# Processing Record 32 of Set 5 | fort mcmurray
# Processing Record 33 of Set 5 | turkmenbasy
# Processing Record 34 of Set 5 | ugbokpo
# Processing Record 35 of Set 5 | hadibu
# Processing Record 36 of Set 5 | cedeira
# Processing Record 37 of Set 5 | lensk
# Processing Record 38 of Set 5 | kotabumi
# Processing Record 39 of Set 5 | arzua
# Processing Record 40 of Set 5 | jordan
# Processing Record 41 of Set 5 | chos malal
# Processing Record 42 of Set 5 | papao
# Processing Record 43 of Set 5 | severo-yeniseyskiy
# Processing Record 44 of Set 5 | jorpeland
# Processing Record 45 of Set 5 | fort bragg
# Processing Record 46 of Set 5 | kerikeri
# Processing Record 47 of Set 5 | praia da vitoria
# Processing Record 48 of Set 5 | phetchabun
# Processing Record 49 of Set 5 | vadso
# Processing Record 0 of Set 6 | bembibre
# Processing Record 1 of Set 6 | northam
# Processing Record 2 of Set 6 | funafuti
# Processing Record 3 of Set 6 | tozeur
# Processing Record 4 of Set 6 | minggang
# Processing Record 5 of Set 6 | ytrebygda
# Processing Record 6 of Set 6 | al wakrah
# Processing Record 7 of Set 6 | rabo de peixe
# Processing Record 8 of Set 6 | al mutayrifi
# Processing Record 9 of Set 6 | mejit
# Processing Record 10 of Set 6 | san patricio
# Processing Record 11 of Set 6 | ekibastuz
# Processing Record 12 of Set 6 | warren
# Processing Record 13 of Set 6 | olonkinbyen
# Processing Record 14 of Set 6 | bima
# Processing Record 15 of Set 6 | melekeok village
# Processing Record 16 of Set 6 | bizhbulyak
# Processing Record 17 of Set 6 | kharkhorin
# Processing Record 18 of Set 6 | bryne
# Processing Record 19 of Set 6 | morehead city
# Processing Record 20 of Set 6 | jabor
# Processing Record 21 of Set 6 | linkou
# Processing Record 22 of Set 6 | nadym
# Processing Record 23 of Set 6 | crane
# Processing Record 24 of Set 6 | mainit
# Processing Record 25 of Set 6 | carnarvon
# Processing Record 26 of Set 6 | benjamin hill
# Processing Record 27 of Set 6 | betio village
# Processing Record 28 of Set 6 | mawu
# Processing Record 29 of Set 6 | la jagua de ibirico
# Processing Record 30 of Set 6 | sarria
# Processing Record 31 of Set 6 | langzhong
# Processing Record 32 of Set 6 | agaro
# Processing Record 33 of Set 6 | mbaiki
# Processing Record 34 of Set 6 | slave lake
# Processing Record 35 of Set 6 | wattegama
# Processing Record 36 of Set 6 | fuvahmulah
# City not found. Skipping...
# Processing Record 37 of Set 6 | tabou
# Processing Record 38 of Set 6 | banyo
# Processing Record 39 of Set 6 | vila velha
# Processing Record 40 of Set 6 | marsh harbour
# Processing Record 41 of Set 6 | holualoa
# Processing Record 42 of Set 6 | zhangye
# Processing Record 43 of Set 6 | hayma'
# City not found. Skipping...
# Processing Record 44 of Set 6 | havre
# Processing Record 45 of Set 6 | manokwari
# Processing Record 46 of Set 6 | nogliki
# Processing Record 47 of Set 6 | alto barinas
# Processing Record 48 of Set 6 | abu dhabi
# Processing Record 49 of Set 6 | ghat
# Processing Record 0 of Set 7 | utrik
# Processing Record 1 of Set 7 | sona
# Processing Record 2 of Set 7 | arroio grande
# Processing Record 3 of Set 7 | ishigaki
# Processing Record 4 of Set 7 | leh
# Processing Record 5 of Set 7 | siguiri
# Processing Record 6 of Set 7 | nar'yan-mar
# Processing Record 7 of Set 7 | vangaindrano
# Processing Record 8 of Set 7 | shahr-e babak
# Processing Record 9 of Set 7 | oskaloosa
# Processing Record 10 of Set 7 | cozumel
# Processing Record 11 of Set 7 | quesnel
# Processing Record 12 of Set 7 | malvan
# Processing Record 13 of Set 7 | penzance
# Processing Record 14 of Set 7 | dourados
# Processing Record 15 of Set 7 | tura
# Processing Record 16 of Set 7 | port said
# Processing Record 17 of Set 7 | narvik
# Processing Record 18 of Set 7 | tubarjal
# Processing Record 19 of Set 7 | kabalo
# Processing Record 20 of Set 7 | mount isa
# Processing Record 21 of Set 7 | strelka
# Processing Record 22 of Set 7 | yuzhno-kurilsk
# Processing Record 23 of Set 7 | thompson
# Processing Record 24 of Set 7 | gadzhiyevo
# Processing Record 25 of Set 7 | ambodivoara
# City not found. Skipping...
# Processing Record 26 of Set 7 | sigli
# Processing Record 27 of Set 7 | mogocha
# Processing Record 28 of Set 7 | bay roberts
# Processing Record 29 of Set 7 | brisas de zicatela
# Processing Record 30 of Set 7 | santa marinella
# Processing Record 31 of Set 7 | smithers
# Processing Record 32 of Set 7 | torghay
# Processing Record 33 of Set 7 | college
# Processing Record 34 of Set 7 | lihue
# Processing Record 35 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 36 of Set 7 | tabas
# Processing Record 37 of Set 7 | taoudenni
# Processing Record 38 of Set 7 | gurmatkal
# Processing Record 39 of Set 7 | dhuusamarreeb
# Processing Record 40 of Set 7 | aitape
# Processing Record 41 of Set 7 | newman
# Processing Record 42 of Set 7 | okha
# Processing Record 43 of Set 7 | dondo
# Processing Record 44 of Set 7 | chiang klang
# Processing Record 45 of Set 7 | mount pearl
# Processing Record 46 of Set 7 | cockburn town
# Processing Record 47 of Set 7 | scinawa
# Processing Record 48 of Set 7 | rongelap
# Processing Record 49 of Set 7 | ad darb
# Processing Record 0 of Set 8 | fort st. john
# Processing Record 1 of Set 8 | pudasjarvi
# Processing Record 2 of Set 8 | pisco
# Processing Record 3 of Set 8 | elliot
# Processing Record 4 of Set 8 | la passe
# Processing Record 5 of Set 8 | rio grande
# Processing Record 6 of Set 8 | timimoun
# Processing Record 7 of Set 8 | riviera beach
# Processing Record 8 of Set 8 | swakopmund
# Processing Record 9 of Set 8 | tulagi
# Processing Record 10 of Set 8 | namibe
# Processing Record 11 of Set 8 | lagoa
# Processing Record 12 of Set 8 | ghanzi
# Processing Record 13 of Set 8 | tanki leendert
# City not found. Skipping...
# Processing Record 14 of Set 8 | 'ain benian
# Processing Record 15 of Set 8 | konarka
# Processing Record 16 of Set 8 | saint-philippe
# Processing Record 17 of Set 8 | veinticinco de mayo
# Processing Record 18 of Set 8 | galesong
# Processing Record 19 of Set 8 | matoury
# Processing Record 20 of Set 8 | belyy yar
# Processing Record 21 of Set 8 | basco
# Processing Record 22 of Set 8 | puerto deseado
# Processing Record 23 of Set 8 | antalaha
# Processing Record 24 of Set 8 | usogorsk
# Processing Record 25 of Set 8 | lesozavodsk
# Processing Record 26 of Set 8 | vilyuysk
# Processing Record 27 of Set 8 | bayan nur
# City not found. Skipping...
# Processing Record 28 of Set 8 | zaraza
# Processing Record 29 of Set 8 | nemuro
# Processing Record 30 of Set 8 | quellon
# Processing Record 31 of Set 8 | fortaleza
# Processing Record 32 of Set 8 | bikenibeu village
# Processing Record 33 of Set 8 | lagos
# Processing Record 34 of Set 8 | cienfuegos
# Processing Record 35 of Set 8 | haiku-pauwela
# Processing Record 36 of Set 8 | kristiansund
# Processing Record 37 of Set 8 | mvomero
# Processing Record 38 of Set 8 | cedartown
# Processing Record 39 of Set 8 | ettelbruck
# Processing Record 40 of Set 8 | curup
# Processing Record 41 of Set 8 | revda
# Processing Record 42 of Set 8 | muzayri'
# City not found. Skipping...
# Processing Record 43 of Set 8 | yoshida-kasugacho
# Processing Record 44 of Set 8 | almeirim
# Processing Record 45 of Set 8 | porto velho
# Processing Record 46 of Set 8 | aksaray
# Processing Record 47 of Set 8 | teluk nibung
# Processing Record 48 of Set 8 | vorkuta
# Processing Record 49 of Set 8 | ulsteinvik
# Processing Record 0 of Set 9 | lecheng
# Processing Record 1 of Set 9 | klaksvik
# Processing Record 2 of Set 9 | kiama
# Processing Record 3 of Set 9 | san jose village
# City not found. Skipping...
# Processing Record 4 of Set 9 | kapa'a
# Processing Record 5 of Set 9 | tinqueux
# Processing Record 6 of Set 9 | shangri-la
# City not found. Skipping...
# Processing Record 7 of Set 9 | yeed
# Processing Record 8 of Set 9 | kapit
# Processing Record 9 of Set 9 | santanyi
# Processing Record 10 of Set 9 | volzhskiy
# Processing Record 11 of Set 9 | hammerfest
# Processing Record 12 of Set 9 | paracuru
# Processing Record 13 of Set 9 | tsiombe
# Processing Record 14 of Set 9 | ayvacik
# Processing Record 15 of Set 9 | natal
# Processing Record 16 of Set 9 | huarmey
# Processing Record 17 of Set 9 | pierre
# Processing Record 18 of Set 9 | kinablangan
# Processing Record 19 of Set 9 | vetluzhskiy
# Processing Record 20 of Set 9 | plainview
# Processing Record 21 of Set 9 | banda aceh
# Processing Record 22 of Set 9 | colonia
# Processing Record 23 of Set 9 | pangkalanbuun
# Processing Record 24 of Set 9 | new norfolk
# Processing Record 25 of Set 9 | katabu
# Processing Record 26 of Set 9 | eldorado
# Processing Record 27 of Set 9 | gisborne
# Processing Record 28 of Set 9 | sausset-les-pins
# Processing Record 29 of Set 9 | walvis bay
# Processing Record 30 of Set 9 | saguenay
# Processing Record 31 of Set 9 | sierra grande
# Processing Record 32 of Set 9 | jiuquan
# Processing Record 33 of Set 9 | seririt
# Processing Record 34 of Set 9 | portland
# Processing Record 35 of Set 9 | prado
# Processing Record 36 of Set 9 | obihiro
# Processing Record 37 of Set 9 | san fernando
# Processing Record 38 of Set 9 | bomdila
# Processing Record 39 of Set 9 | gorele
# Processing Record 40 of Set 9 | waddan
# Processing Record 41 of Set 9 | kourou
# Processing Record 42 of Set 9 | kalmunai
# Processing Record 43 of Set 9 | westport
# Processing Record 44 of Set 9 | laurel
# Processing Record 45 of Set 9 | mitsamiouli
# Processing Record 46 of Set 9 | erbil
# Processing Record 47 of Set 9 | polyarnyye zori
# Processing Record 48 of Set 9 | dunedin
# Processing Record 49 of Set 9 | ghadamis
# Processing Record 0 of Set 10 | san antonio
# Processing Record 1 of Set 10 | kijang
# Processing Record 2 of Set 10 | evanston
# Processing Record 3 of Set 10 | togitsu
# Processing Record 4 of Set 10 | itaituba
# Processing Record 5 of Set 10 | n'zeto
# Processing Record 6 of Set 10 | brookings
# Processing Record 7 of Set 10 | lianzhou
# Processing Record 8 of Set 10 | ciudad insurgentes
# Processing Record 9 of Set 10 | nykobing sjaelland
# Processing Record 10 of Set 10 | horta
# Processing Record 11 of Set 10 | hirara
# Processing Record 12 of Set 10 | shulan
# Processing Record 13 of Set 10 | chake chake
# Processing Record 14 of Set 10 | calabozo
# Processing Record 15 of Set 10 | itoman
# Processing Record 16 of Set 10 | ulanhot
# Processing Record 17 of Set 10 | erdenet
# Processing Record 18 of Set 10 | sydney mines
# Processing Record 19 of Set 10 | malabar
# Processing Record 20 of Set 10 | kaiyuan
# Processing Record 21 of Set 10 | sorong
# Processing Record 22 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 23 of Set 10 | sarangani
# Processing Record 24 of Set 10 | tawau
# Processing Record 25 of Set 10 | igarka
# Processing Record 26 of Set 10 | sirdaryo
# Processing Record 27 of Set 10 | verkhniy mamon
# Processing Record 28 of Set 10 | ola
# Processing Record 29 of Set 10 | isabela
# Processing Record 30 of Set 10 | ketchikan
# Processing Record 31 of Set 10 | ulan bator
# Processing Record 32 of Set 10 | mhamid
# Processing Record 33 of Set 10 | reggane
# Processing Record 34 of Set 10 | olyokminsk
# Processing Record 35 of Set 10 | kone
# Processing Record 36 of Set 10 | mil'kovo
# Processing Record 37 of Set 10 | springbok
# Processing Record 38 of Set 10 | tasbuget
# City not found. Skipping...
# Processing Record 39 of Set 10 | broken hill
# Processing Record 40 of Set 10 | turochak
# Processing Record 41 of Set 10 | puerto cabezas
# Processing Record 42 of Set 10 | manismata
# Processing Record 43 of Set 10 | kikwit
# Processing Record 44 of Set 10 | homer
# Processing Record 45 of Set 10 | saint-francois
# Processing Record 46 of Set 10 | burutu
# Processing Record 47 of Set 10 | siwa oasis
# Processing Record 48 of Set 10 | mirny
# Processing Record 49 of Set 10 | pingliang
# Processing Record 0 of Set 11 | zuni pueblo
# Processing Record 1 of Set 11 | ambilobe
# Processing Record 2 of Set 11 | wad medani
# Processing Record 3 of Set 11 | talara
# Processing Record 4 of Set 11 | castillos
# Processing Record 5 of Set 11 | bealanana
# Processing Record 6 of Set 11 | genhe
# Processing Record 7 of Set 11 | crucecita
# Processing Record 8 of Set 11 | deir ez-zor
# Processing Record 9 of Set 11 | hithadhoo
# Processing Record 10 of Set 11 | concordia
# Processing Record 11 of Set 11 | ulladulla
# Processing Record 12 of Set 11 | loncoche
# Processing Record 13 of Set 11 | jwaneng
# Processing Record 14 of Set 11 | raigarh
# Processing Record 15 of Set 11 | puerto baquerizo moreno
# Processing Record 16 of Set 11 | motygino
# Processing Record 17 of Set 11 | aginskoye
# Processing Record 18 of Set 11 | askoy
# Processing Record 19 of Set 11 | san jeronimo
# Processing Record 20 of Set 11 | tengrela
# Processing Record 21 of Set 11 | kruisfontein
# Processing Record 22 of Set 11 | santa luzia
# Processing Record 23 of Set 11 | shenjiamen
# Processing Record 24 of Set 11 | inebolu
# Processing Record 25 of Set 11 | priargunsk
# Processing Record 26 of Set 11 | san antonio de pale
# Processing Record 27 of Set 11 | nahiyat al fuhud
# Processing Record 28 of Set 11 | kanggye
# Processing Record 29 of Set 11 | murun-kuren
# Processing Record 30 of Set 11 | talen
# Processing Record 31 of Set 11 | buka
# Processing Record 32 of Set 11 | micheweni
# Processing Record 33 of Set 11 | champerico
# Processing Record 34 of Set 11 | guayaramerin
# Processing Record 35 of Set 11 | menongue
# Processing Record 36 of Set 11 | megion
# Processing Record 37 of Set 11 | teguise
# Processing Record 38 of Set 11 | udobnaya
# Processing Record 39 of Set 11 | vila franca do campo
# Processing Record 40 of Set 11 | floriano
# Processing Record 41 of Set 11 | sola
# Processing Record 42 of Set 11 | beaconsfield
# Processing Record 43 of Set 11 | medina
# Processing Record 44 of Set 11 | zapala
# Processing Record 45 of Set 11 | geraldton
# Processing Record 46 of Set 11 | sao lourenco do sul
# Processing Record 47 of Set 11 | ca mau
# Processing Record 48 of Set 11 | ubinskoye
# Processing Record 49 of Set 11 | terrace
# Processing Record 0 of Set 12 | trincomalee
# Processing Record 1 of Set 12 | peniche
# Processing Record 2 of Set 12 | inhambane
# Processing Record 3 of Set 12 | tvoroyri
# Processing Record 4 of Set 12 | usinsk
# Processing Record 5 of Set 12 | viljandi
# Processing Record 6 of Set 12 | lotoshino
# Processing Record 7 of Set 12 | muntok
# Processing Record 8 of Set 12 | wanning
# Processing Record 9 of Set 12 | chernyshevskiy
# Processing Record 10 of Set 12 | piti village
# Processing Record 11 of Set 12 | haradok
# Processing Record 12 of Set 12 | anloga
# Processing Record 13 of Set 12 | levuka
# Processing Record 14 of Set 12 | cidade velha
# Processing Record 15 of Set 12 | chinde
# Processing Record 16 of Set 12 | lichuan
# Processing Record 17 of Set 12 | carrizo springs
# Processing Record 18 of Set 12 | fianarantsoa
# Processing Record 19 of Set 12 | howrah
# Processing Record 20 of Set 12 | vanino
# Processing Record 21 of Set 12 | luganville
# Processing Record 22 of Set 12 | kharp
# Processing Record 23 of Set 12 | lompoc
# Processing Record 24 of Set 12 | qulsary
# Processing Record 25 of Set 12 | bodo
# Processing Record 26 of Set 12 | chonchi
# Processing Record 27 of Set 12 | bandundu
# Processing Record 28 of Set 12 | kuala terengganu
# Processing Record 29 of Set 12 | kralendijk
# Processing Record 30 of Set 12 | lewiston orchards
# Processing Record 31 of Set 12 | gamboula
# Processing Record 32 of Set 12 | caleta de carquin
# Processing Record 33 of Set 12 | gabarin
# Processing Record 34 of Set 12 | sao tome
# Processing Record 35 of Set 12 | puerto santa
# Processing Record 36 of Set 12 | salekhard
# Processing Record 37 of Set 12 | maputo
# Processing Record 38 of Set 12 | yemetsk
# Processing Record 39 of Set 12 | hotan
# Processing Record 40 of Set 12 | broome
# Processing Record 41 of Set 12 | amherst
# Processing Record 42 of Set 12 | nguigmi
# Processing Record 43 of Set 12 | gaiman
# Processing Record 44 of Set 12 | port hueneme
# Processing Record 45 of Set 12 | zheleznodorozhnyy
# Processing Record 46 of Set 12 | severnoye
# Processing Record 47 of Set 12 | nuku'alofa
# Processing Record 48 of Set 12 | pontarlier
# Processing Record 49 of Set 12 | howard springs
# Processing Record 0 of Set 13 | okakarara
# Processing Record 1 of Set 13 | saldanha
# Processing Record 2 of Set 13 | hilo
# Processing Record 3 of Set 13 | san julian
# Processing Record 4 of Set 13 | tayaman
# Processing Record 5 of Set 13 | bulungu
# Processing Record 6 of Set 13 | tevragh zeina
# City not found. Skipping...
# Processing Record 7 of Set 13 | svatove
# Processing Record 8 of Set 13 | sao jose da coroa grande
# Processing Record 9 of Set 13 | puerto el triunfo
# Processing Record 10 of Set 13 | ninghai
# Processing Record 11 of Set 13 | taltal
# Processing Record 12 of Set 13 | nukus
# Processing Record 13 of Set 13 | kidal
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_weather
# Out:
# {'coord': {'lon': 1.4078, 'lat': 18.4411},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 28.79,
#   'feels_like': 27.2,
#   'temp_min': 28.79,
#   'temp_max': 28.79,
#   'pressure': 1012,
#   'humidity': 11,
#   'sea_level': 1012,
#   'grnd_level': 961},
#  'visibility': 10000,
#  'wind': {'speed': 2.71, 'deg': 309, 'gust': 2.92},
#  'clouds': {'all': 1},
#  'dt': 1699558671,
#  'sys': {'country': 'ML', 'sunrise': 1699509455, 'sunset': 1699550328},
#  'timezone': 0,
#  'id': 2455290,
#  'name': 'Kidal',
#  'cod': 200}

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df

# Show Record Count
city_data_df.count()
# Out:
# City          592
# Lat           592
# Lng           592
# Max Temp      592
# Humidity      592
# Cloudiness    592
# Wind Speed    592
# Country       592
# Date          592
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  remire-montjoly   4.9167  -52.2667     31.02        62         100
# 1      yellowknife  62.4560 -114.3525     -0.88        98         100
# 2     longyearbyen  78.2186   15.6401     -2.09        74          75
# 3         midvagur  62.0511   -7.1939      5.46        87          75
# 4  nieuw amsterdam   5.8833  -55.0833     34.09        59          20
#
#    Wind Speed Country        Date
# 0        6.17      GF  1699558705
# 1        9.26      CA  1699558559
# 2        6.17      SJ  1699558582
# 3        4.12      FO  1699558760
# 4        3.09      SR  1699558760

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        remire-montjoly   4.9167  -52.2667     31.02        62         100
# 1            yellowknife  62.4560 -114.3525     -0.88        98         100
# 2           longyearbyen  78.2186   15.6401     -2.09        74          75
# 3               midvagur  62.0511   -7.1939      5.46        87          75
# 4        nieuw amsterdam   5.8833  -55.0833     34.09        59          20
#
#          Wind Speed Country        Date
# City_ID
# 0              6.17      GF  1699558705
# 1              9.26      CA  1699558559
# 2              6.17      SJ  1699558582
# 3              4.12      FO  1699558760
# 4              3.09      SR  1699558760

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_values = city_data_df['Lat']
y_values = city_data_df['Max Temp']
plt.scatter(x_values,y_values,marker="o",facecolors='blue',edgecolors='black',)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.grid(True)

# Incorporate the other graph properties
plt.title('City Latitude vs Max Temperature (2023-11-9)')

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_values = city_data_df['Lat']
y_values = city_data_df['Humidity']
plt.scatter(x_values,y_values,marker="o",facecolors='blue',edgecolors='black',)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)

# Incorporate the other graph properties
plt.title('City Latitude vs Humidity (2023-11-9)')

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_values = city_data_df['Lat']
y_values = city_data_df['Cloudiness']
plt.scatter(x_values,y_values,marker="o",facecolors='blue',edgecolors='black',)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)

# Incorporate the other graph properties
plt.title('City Latitude vs Cloudiness (2023-11-9)')

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_values = city_data_df['Lat']
y_values = city_data_df['Wind Speed']
plt.scatter(x_values,y_values,marker="o",facecolors='blue',edgecolors='black',)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.grid(True)


# Incorporate the other graph properties
plt.title('City Latitude vs Wind Speed (2023-11-9)')

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linearRegression(x_values,y_values, regEQplotX, regEQplotY, ylabel):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values, marker="o", facecolors="blue")
    plt.plot(x_values,regress_values,"r-", linewidth=3)
    plt.grid(True)
    print(f'The r-value is {rvalue}')
    plt.annotate(line_eq,(regEQplotX,regEQplotY),color="red")
    plt.xlabel('Latitude')
    plt.ylabel(f'{ylabel}')
    plt.grid()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)city_data_df
northern_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]).astype(float)>= 0, :]
northern_hemi_df
# Display sample data
northern_hemi_df.head()
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        remire-montjoly   4.9167  -52.2667     31.02        62         100
# 1            yellowknife  62.4560 -114.3525     -0.88        98         100
# 2           longyearbyen  78.2186   15.6401     -2.09        74          75
# 3               midvagur  62.0511   -7.1939      5.46        87          75
# 4        nieuw amsterdam   5.8833  -55.0833     34.09        59          20
#
#          Wind Speed Country        Date
# City_ID
# 0              6.17      GF  1699558705
# 1              9.26      CA  1699558559
# 2              6.17      SJ  1699558582
# 3              4.12      FO  1699558760
# 4              3.09      SR  1699558760

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]).astype(float)< 0, :]
southern_hemi_df

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 5        port-aux-francais -49.3500   70.2167      5.33        95         100
# 6            blackmans bay -43.0167  147.3167     13.07        95          30
# 7           margaret river -33.9500  115.0667     13.35        66         100
# 8        sao joao da barra -21.6403  -41.0511     30.05        77           0
# 10                  uturoa -16.7333 -151.4333     26.21        83           3
#
#          Wind Speed Country        Date
# City_ID
# 5             11.85      TF  1699558574
# 6              1.18      AU  1699558585
# 7              4.22      AU  1699558594
# 8              7.66      BR  1699558761
# 10             6.57      PF  1699558643

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_plot = northern_hemi_df["Lat"]
y_plot = northern_hemi_df["Max Temp"]
linearRegression(x_plot, y_plot, 5, -20, "Temperature (C)")
plt.savefig("output_data/Fig5.png",dpi=300, bbox_inches = "tight")
# Out:
# The r-value is -0.8324760524559693

# %%
# Linear regression on Southern Hemisphere
x_plot = southern_hemi_df["Lat"]
y_plot = southern_hemi_df["Max Temp"]
linearRegression(x_plot, y_plot, -55, 35, "Temperature (C)")
plt.savefig("output_data/Fig6.png",dpi=300, bbox_inches = "tight")
# Out:
# The r-value is 0.685997681792818

# %% [markdown]
# Discussion about the linear relationship:
# Latitude vs Temperature - As expected, the farther away from the equator we travel, the max temperature is lower.  Both r-values are high enough to show that there is a correlation.  The r-value correlation is slightly higher in the northern hemisphere.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_plot = northern_hemi_df["Lat"]
y_plot = northern_hemi_df["Humidity"]
linearRegression(x_plot, y_plot, 50, 20, "Humidity (%)")
plt.savefig("output_data/Fig7.png",dpi=300, bbox_inches = "tight")
# Out:
# The r-value is 0.2614719658313944

# %%
# Southern Hemisphere
x_plot = southern_hemi_df["Lat"]
y_plot = southern_hemi_df["Humidity"]
linearRegression(x_plot, y_plot, -15, 10, "Humidity (%)")
plt.savefig("output_data/Fig8.png",dpi=300, bbox_inches = "tight")
# Out:
# The r-value is 0.280820030700022

# %% [markdown]
# Discussion about the linear relationship:
# According to the data, there is no correlation of the level of humidity compared to the distance from the equator.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_plot = northern_hemi_df["Lat"]
y_plot = northern_hemi_df["Cloudiness"]
linearRegression(x_plot, y_plot, 50, 10, "Cloudiness (%)")
plt.savefig("output_data/Fig7.png",dpi=300, bbox_inches = "tight")
# Out:
# The r-value is 0.08867287668515392

# %%
# Southern Hemisphere
x_plot = southern_hemi_df["Lat"]
y_plot = southern_hemi_df["Cloudiness"]
linearRegression(x_plot, y_plot, -50, 50, "Cloudiness (%)")
plt.savefig("output_data/Fig7.png",dpi=300, bbox_inches = "tight")
# Out:
# The r-value is 0.20730170173804577

# %% [markdown]
# Discussion about the linear relationship:
# There is a slightly higher correlation in the southern atmosphere.  But there is still no significant correlation between cloudiness and distance from the equator.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_plot = northern_hemi_df["Lat"]
y_plot = northern_hemi_df["Wind Speed"]
linearRegression(x_plot, y_plot, 50, 15, "Wind Speed (m/s)")
plt.savefig("output_data/Fig7.png",dpi=300, bbox_inches = "tight")
# Out:
# The r-value is 0.12407830815900184

# %%
# Southern Hemisphere
x_plot = southern_hemi_df["Lat"]
y_plot = southern_hemi_df["Wind Speed"]
linearRegression(x_plot, y_plot, -50, 10, "Wind Speed (m/s)")
plt.savefig("output_data/Fig7.png",dpi=300, bbox_inches = "tight")
# Out:
# The r-value is -0.11200500615180621

# %% [markdown]
# Discussion about the linear relationship:
# According to the data, there is no correlation of the level of humidity compared to the distance from the equator.
